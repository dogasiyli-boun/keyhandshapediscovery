# %% [markdown]
# Importing Modules

# %%
import torch
import torchvision
import torch.nn as nn
import matplotlib
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch.optim as optim
import os
import time
import numpy as np
import argparse
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision.utils import save_image
matplotlib.style.use('ggplot')
import sys, importlib as impL
sys.path.insert(1,'/home/wsubuntu/GitHub/keyhandshapediscovery')
import helperFuncs as funcH
import pandas as pd

# %%
def calc_bottleneck_acc(bottleneck_vec, lab_vec):
    pred_vec = np.argmax(bottleneck_vec.T, axis=0).T.squeeze()
    centroid_info_pdf = funcH.get_cluster_centroids(bottleneck_vec, pred_vec, kluster_centers=None, verbose=0)
    _confMat_preds, kluster2Classes, kr_pdf, weightedPurity, cnmxh_perc = funcH.countPredictionsForConfusionMat(lab_vec, pred_vec, centroid_info_pdf=centroid_info_pdf, labelNames=None)
    sampleCount = np.sum(np.sum(_confMat_preds))
    acc = 100 * np.sum(np.diag(_confMat_preds)) / sampleCount
    bmx, bmn = np.max(bottleneck_vec), np.min(bottleneck_vec)
    return acc, bmx, bmn

funcH.setPandasDisplayOpts()

# %% [markdown]
# Constructing the Argument Parsers

# %%
#ap = argparse.ArgumentParser()
#ap.add_argument('-e', '--epochs', type=int, default=10, help='number of epochs to train our network for')
#ap.add_argument('-l', '--reg_param', type=float, default=0.001, help='regularization parameter `lambda`')
#ap.add_argument('-sc', '--add_sparse', type=str, default='yes', help='whether to add sparsity contraint or not')
#args = vars(ap.parse_args())
epochs = 100  # args['epochs']
reg_param = 0.001  # args['reg_param']
add_sparsity = 'yes'  # args['add_sparse']
learning_rate = 1e-4
batch_size = 32
print(f"Add sparsity regularization: {add_sparsity}")
# Out:
# Add sparsity regularization: yes

# %% [markdown]
# here I will change the data loader per my need

# %%
# get the computation device
def get_device():
    return 'cuda:0' if torch.cuda.is_available() else 'cpu'
device = get_device()
print(device)
# Out:
# cpu

# %%
# image transformations
transform = transforms.Compose([
    transforms.ToTensor(),
])

FOLDERS = {
    "data": '/media/wsubuntu/SSD_Data/DataPath',
    "experiment": '/media/wsubuntu/SSD_Data/vaesae_experiments/sparse_torch_ae_ws_002',
}
FOLDERS["model_save"] = os.path.join(FOLDERS["experiment"], "model")
FOLDERS["decoder_image_path_tr"] = os.path.join(FOLDERS["experiment"], "output_images_tr")
FOLDERS["decoder_image_path_va"] = os.path.join(FOLDERS["experiment"], "output_images_va")
funcH.createDirIfNotExist(FOLDERS["model_save"])
funcH.createDirIfNotExist(FOLDERS["decoder_image_path_tr"])
funcH.createDirIfNotExist(FOLDERS["decoder_image_path_va"])

trainset = datasets.FashionMNIST(
    root=FOLDERS["data"],
    train=True, 
    download=True,
    transform=transform
)
testset = datasets.FashionMNIST(
    root=FOLDERS["data"],
    train=False,
    download=True,
    transform=transform
)
 
# trainloader
trainloader = DataLoader(
    trainset, 
    batch_size=batch_size,
    shuffle=True
)
#testloader
testloader = DataLoader(
    testset, 
    batch_size=batch_size, 
    shuffle=False
)

# %%
# define the autoencoder model
class SparseAutoencoder(nn.Module):
    def __init__(self, loss_type):
        super(SparseAutoencoder, self).__init__()
 
        # encoder
        self.enc1 = nn.Linear(in_features=784, out_features=256)
        self.enc2 = nn.Linear(in_features=256, out_features=128)
        self.enc3 = nn.Linear(in_features=128, out_features=64)
        self.enc4 = nn.Linear(in_features=64, out_features=32)
        self.enc5 = nn.Linear(in_features=32, out_features=16)
 
        # decoder 
        self.dec1 = nn.Linear(in_features=16, out_features=32)
        self.dec2 = nn.Linear(in_features=32, out_features=64)
        self.dec3 = nn.Linear(in_features=64, out_features=128)
        self.dec4 = nn.Linear(in_features=128, out_features=256)
        self.dec5 = nn.Linear(in_features=256, out_features=784)
        
        self.loss_type=loss_type
        self.device = get_device()
 
    def forward(self, x):
        # encoding
        x = F.relu(self.enc1(x))
        x = F.relu(self.enc2(x))
        x = F.relu(self.enc3(x))
        x = F.relu(self.enc4(x))
        bottleneck = F.relu(self.enc5(x))

        # decoding
        x = F.relu(self.dec1(bottleneck))
        x = F.relu(self.dec2(x))
        x = F.relu(self.dec3(x))
        x = F.relu(self.dec4(x))
        x = F.relu(self.dec5(x))
        return x, bottleneck
model = SparseAutoencoder(loss_type='l1').to(device)

# %%
# the loss function
criterion = nn.MSELoss()
# the optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# get the layers as a list
model_children = list(model.children())
[print(i) for i in model_children]
# Out:
# Linear(in_features=784, out_features=256, bias=True)
# Linear(in_features=256, out_features=128, bias=True)
# Linear(in_features=128, out_features=64, bias=True)
# Linear(in_features=64, out_features=32, bias=True)
# Linear(in_features=32, out_features=16, bias=True)
# Linear(in_features=16, out_features=32, bias=True)
# Linear(in_features=32, out_features=64, bias=True)
# Linear(in_features=64, out_features=128, bias=True)
# Linear(in_features=128, out_features=256, bias=True)
# Linear(in_features=256, out_features=784, bias=True)
# [None, None, None, None, None, None, None, None, None, None]

# %%
def loss_l1(bottleneck):
    return torch.mean(torch.abs(bottleneck))

def loss_l2(bottleneck):
    return torch.mean(torch.pow(bottleneck, torch.tensor(2.0).to(device))).sqrt()

def kl_divergence(bottleneck):
    rho = 0.05
    bottleneck = torch.mean(torch.sigmoid(bottleneck), 1)  # sigmoid because we need the probability distributions
    rho = torch.tensor([rho] * len(bottleneck)).to(device)
    loss_ret_1 = torch.nn.functional.kl_div(bottleneck, rho, reduction='batchmean')
    # torch.sum(rho * torch.log(rho / bottleneck) + (1 - rho) * torch.log((1 - rho) / (1 - bottleneck)))
    return loss_ret_1

# %%
# define the sparse loss function
def sparse_loss(autoencoder, images, print_info, loss_type):
    loss = 0
    values = images
    for i in range(len(model_children)):
        values = F.relu((model_children[i](values)))
        #if print_info:
            #print(i, ' shape=', values.shape)
        if loss_type=='l1':
            loss += loss_l1(values)
        if loss_type=='l2':
            loss += loss_l2(values)
        if loss_type=='kl':
            loss += kl_divergence(values)
        if print_info:
            print(loss_type,loss)
    return loss

# %%
def save_decoded_image(img, name):
    img = img.view(img.size(0), 1, 28, 28)
    save_image(img, name)

# define the training function
def fit(model, dataloader, epoch, print_losses_fit):
    print('TrEpoch({:03d}) - '.format(epoch), end='')
    model.train()
    running_loss = 0.0
    
    lab_vec = []
    bottleneck_vec = []
    sparsity_loss_sum = 0
    mse_sum = 0
       
    for data in dataloader:
        img, lb = data
        lab_vec.append(lb)
        
        img = img.to(device)
        img = img.view(img.size(0), -1)
        optimizer.zero_grad()
        outputs, bottleneck = model(img)
        bottleneck_vec.append(bottleneck)
        mse_loss = criterion(outputs, img)
        mse_sum += mse_loss.item()
        #if print_losses_fit:
            #print("mse_loss:", mse_loss.to('cpu'))
            #print("bottleneck:", bottleneck.to('cpu'))
        if add_sparsity == 'yes':
            sp_loss = sparse_loss(model, img, print_losses_fit, model.loss_type)
            sparsity_loss_sum += sp_loss.item()
            # add the sparsity penalty
            if print_losses_fit:
                print("sp_loss:", sparsity_loss_sum)
            loss = mse_loss + reg_param * sp_loss
        else:
            loss = mse_loss
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        print_losses_fit = False
    
    lab_vec = np.asarray(torch.cat(lab_vec).to(torch.device('cpu')))
    bottleneck_vec = np.asarray(torch.cat(bottleneck_vec).to(torch.device('cpu')).detach().numpy())
    acc, bmx, bmn = calc_bottleneck_acc(bottleneck_vec, lab_vec)
    #print("tr bottleneck accuracy=", acc, ", max=", bmx, ", min=", bmn, ", sparsity_loss_sum=", sparsity_loss_sum)
  
    result_df = pd.DataFrame(np.array([[acc, bmx, bmn, mse_sum, sparsity_loss_sum, running_loss]]), columns=['acc','bmx','bmn','mse','spr','run'])
    #print(df.iloc[0]['mse']) #'acc','bmx','bmn','mse','spr','run'
    print("\n",result_df)
    if epoch % 2 == 0:
        difn = os.path.join(FOLDERS["decoder_image_path_tr"], "train"+str(epoch).zfill(3)+".png")
        save_decoded_image(outputs.cpu().data, difn)
    return result_df

# %%
# define the validation function
def validate(model, dataloader, epoch, print_losses_fit):
    print('ValEpoch({:03d}) - '.format(epoch), end='')
    model.eval()
    running_loss = 0.0
    lab_vec = []
    bottleneck_vec = []
    with torch.no_grad():
        for data in dataloader:
            img, lb = data
            lab_vec.append(lb)
            img = img.to(device)
            img = img.view(img.size(0), -1)
            outputs, bottleneck = model(img)
            bottleneck_vec.append(bottleneck)
            loss = criterion(outputs, img)
            running_loss += loss.item()
    # save the reconstructed images every 5 epochs
    lab_vec = np.asarray(torch.cat(lab_vec).to(torch.device('cpu')))
    bottleneck_vec = np.asarray(torch.cat(bottleneck_vec).to(torch.device('cpu')).detach().numpy())
    acc, bmx, bmn = calc_bottleneck_acc(bottleneck_vec, lab_vec)

    result_df = pd.DataFrame(np.array([[acc, bmx, bmn, running_loss]]), columns=['acc','bmx','bmn','run'])
    print("\n",result_df)
    
    if epoch % 2 == 0:
        outputs = outputs.view(outputs.size(0), 1, 28, 28).cpu().data
        difn = os.path.join(FOLDERS["decoder_image_path_va"], "reconstruction"+str(epoch).zfill(3)+".png")
        save_image(outputs, difn)
    return result_df

# %%
# train and validate the autoencoder neural network
start = time.time()
print_losses_fit = True

train_loss = []
trn_spars_loss = []
trn_bot_acc = []
val_loss = []
val_bot_acc = []

result_df_tr_all = pd.DataFrame(columns=['acc','bmx','bmn','mse','spr','run'])
result_df_va_all = pd.DataFrame(columns=['acc','bmx','bmn','run'])

print("stae_ws05_02 - l1 - loss = mse_loss **+** reg_param * sp_loss")

for epoch in range(epochs):
    print(f"*****\n Epoch {epoch} of {epochs}")
    result_df_tr = fit(model, trainloader, epoch, print_losses_fit)
    result_df_va = validate(model, testloader, epoch, print_losses_fit)
    print_losses_fit = epoch%5==0 and epoch>0
    result_df_tr_all = result_df_tr_all.append(result_df_tr, ignore_index=True)
    result_df_va_all = result_df_va_all.append(result_df_va, ignore_index=True)
    
end = time.time()
 
print(f"{(end-start)/60:.3} minutes")
# save the trained model

mofn = os.path.join(FOLDERS["model_save"], "sparse_ae_"+str(epoch).zfill(3)+".pth")
torch.save(model.state_dict(), mofn)
# Out:
# stae_ws05_02 - l1 - loss = mse_loss **+** reg_param * sp_loss
# *****
#  Epoch 0 of 100
# TrEpoch(000) - l1 tensor(0.1170, grad_fn=<AddBackward0>)
# l1 tensor(0.1725, grad_fn=<AddBackward0>)
# l1 tensor(0.1969, grad_fn=<AddBackward0>)
# l1 tensor(0.2304, grad_fn=<AddBackward0>)
# l1 tensor(0.2745, grad_fn=<AddBackward0>)
# l1 tensor(0.3567, grad_fn=<AddBackward0>)
# l1 tensor(0.4071, grad_fn=<AddBackward0>)
# l1 tensor(0.4479, grad_fn=<AddBackward0>)
# l1 tensor(0.4787, grad_fn=<AddBackward0>)
# l1 tensor(0.4975, grad_fn=<AddBackward0>)
# sp_loss: 0.4974929690361023
#
#       acc    bmx  bmn      mse       spr     run
# 0  10.34  3.569  0.0  198.533  2457.281  200.99
# ValEpoch(000) -
#      acc    bmx  bmn     run
# 0  8.08  3.094  0.0  21.638
# *****
#  Epoch 1 of 100
# TrEpoch(001) -
#        acc    bmx  bmn      mse       spr      run
# 0  18.938  3.564  0.0  114.773  2574.492  117.347
# ValEpoch(001) -
#       acc    bmx  bmn     run
# 0  19.04  2.582  0.0  17.904
# *****
#  Epoch 2 of 100
# TrEpoch(002) -
#        acc    bmx  bmn     mse       spr      run
# 0  20.305  2.683  0.0  102.26  2466.176  104.726
# ValEpoch(002) -
#       acc    bmx  bmn     run
# 0  19.65  2.818  0.0  16.543
# *****
#  Epoch 3 of 100
# TrEpoch(003) -
#       acc    bmx  bmn     mse       spr     run
# 0  19.67  2.499  0.0  92.352  2412.836  94.764
# ValEpoch(003) -
#       acc   bmx  bmn     run
# 0  23.52  2.34  0.0  13.886
# *****
#  Epoch 4 of 100
# TrEpoch(004) -
#        acc   bmx  bmn     mse       spr     run
# 0  23.177  2.16  0.0  75.472  2574.698  78.047
# ValEpoch(004) -
#       acc   bmx  bmn     run
# 0  24.35  2.03  0.0  11.809
# *****
#  Epoch 5 of 100
# TrEpoch(005) -
#        acc    bmx  bmn     mse       spr     run
# 0  25.953  2.055  0.0  67.901  2545.863  70.447
# ValEpoch(005) -
#       acc    bmx  bmn     run
# 0  23.21  1.985  0.0  10.947
# *****
#  Epoch 6 of 100
# TrEpoch(006) - l1 tensor(0.0611, grad_fn=<AddBackward0>)
# l1 tensor(0.1184, grad_fn=<AddBackward0>)
# l1 tensor(0.1887, grad_fn=<AddBackward0>)
# l1 tensor(0.3040, grad_fn=<AddBackward0>)
# l1 tensor(0.4435, grad_fn=<AddBackward0>)
# l1 tensor(0.5896, grad_fn=<AddBackward0>)
# l1 tensor(0.7351, grad_fn=<AddBackward0>)
# l1 tensor(0.9140, grad_fn=<AddBackward0>)
# l1 tensor(1.0955, grad_fn=<AddBackward0>)
# l1 tensor(1.3900, grad_fn=<AddBackward0>)
# sp_loss: 1.389986515045166
#
#       acc    bmx  bmn    mse       spr    run
# 0  28.56  2.031  0.0  63.97  2449.728  66.42
# ValEpoch(006) -
#       acc    bmx  bmn     run
# 0  24.62  1.791  0.0  10.574
# *****
#  Epoch 7 of 100
# TrEpoch(007) -
#        acc    bmx  bmn     mse       spr     run
# 0  28.302  1.963  0.0  62.313  2371.121  64.684
# ValEpoch(007) -
#       acc    bmx  bmn     run
# 0  24.75  1.798  0.0  10.334
# *****
#  Epoch 8 of 100
# TrEpoch(008) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.335  1.835  0.0  61.034  2327.248  63.361
# ValEpoch(008) -
#       acc    bmx  bmn     run
# 0  29.59  1.571  0.0  10.156
# *****
#  Epoch 9 of 100
# TrEpoch(009) -
#       acc    bmx  bmn     mse       spr     run
# 0  28.45  1.718  0.0  60.055  2286.423  62.342
# ValEpoch(009) -
#       acc    bmx  bmn   run
# 0  27.54  1.593  0.0  10.0
# *****
#  Epoch 10 of 100
# TrEpoch(010) -
#        acc    bmx  bmn     mse     spr     run
# 0  29.287  1.616  0.0  58.706  2251.9  60.958
# ValEpoch(010) -
#       acc    bmx  bmn    run
# 0  27.37  1.561  0.0  9.736
# *****
#  Epoch 11 of 100
# TrEpoch(011) - l1 tensor(0.0506, grad_fn=<AddBackward0>)
# l1 tensor(0.0907, grad_fn=<AddBackward0>)
# l1 tensor(0.1332, grad_fn=<AddBackward0>)
# l1 tensor(0.2052, grad_fn=<AddBackward0>)
# l1 tensor(0.2967, grad_fn=<AddBackward0>)
# l1 tensor(0.4043, grad_fn=<AddBackward0>)
# l1 tensor(0.5150, grad_fn=<AddBackward0>)
# l1 tensor(0.6632, grad_fn=<AddBackward0>)
# l1 tensor(0.8220, grad_fn=<AddBackward0>)
# l1 tensor(1.0774, grad_fn=<AddBackward0>)
# sp_loss: 1.07740318775177
#
#        acc    bmx  bmn     mse       spr     run
# 0  28.952  1.598  0.0  57.515  2219.898  59.735
# ValEpoch(011) -
#      acc    bmx  bmn    run
# 0  23.2  1.488  0.0  9.592
# *****
#  Epoch 12 of 100
# TrEpoch(012) -
#        acc    bmx  bmn     mse       spr     run
# 0  20.335  1.563  0.0  56.886  2183.527  59.069
# ValEpoch(012) -
#      acc    bmx  bmn    run
# 0  25.0  1.477  0.0  9.525
# *****
#  Epoch 13 of 100
# TrEpoch(013) -
#        acc    bmx  bmn     mse       spr     run
# 0  23.167  1.484  0.0  56.333  2150.861  58.484
# ValEpoch(013) -
#       acc    bmx  bmn    run
# 0  24.12  1.365  0.0  9.442
# *****
#  Epoch 14 of 100
# TrEpoch(014) -
#        acc    bmx  bmn     mse       spr     run
# 0  24.813  1.454  0.0  55.731  2128.642  57.859
# ValEpoch(014) -
#       acc    bmx  bmn    run
# 0  21.17  1.504  0.0  9.335
# *****
#  Epoch 15 of 100
# TrEpoch(015) -
#        acc    bmx  bmn     mse       spr     run
# 0  25.542  1.461  0.0  55.076  2110.468  57.187
# ValEpoch(015) -
#      acc    bmx  bmn    run
# 0  25.2  1.432  0.0  9.209
# *****
#  Epoch 16 of 100
# TrEpoch(016) - l1 tensor(0.0436, grad_fn=<AddBackward0>)
# l1 tensor(0.0818, grad_fn=<AddBackward0>)
# l1 tensor(0.1230, grad_fn=<AddBackward0>)
# l1 tensor(0.1922, grad_fn=<AddBackward0>)
# l1 tensor(0.2830, grad_fn=<AddBackward0>)
# l1 tensor(0.3832, grad_fn=<AddBackward0>)
# l1 tensor(0.4946, grad_fn=<AddBackward0>)
# l1 tensor(0.6436, grad_fn=<AddBackward0>)
# l1 tensor(0.8041, grad_fn=<AddBackward0>)
# l1 tensor(1.0538, grad_fn=<AddBackward0>)
# sp_loss: 1.0537705421447754
#
#        acc    bmx  bmn     mse       spr     run
# 0  27.237  1.396  0.0  54.503  2084.872  56.588
# ValEpoch(016) -
#       acc    bmx  bmn    run
# 0  21.03  1.408  0.0  9.147
# *****
#  Epoch 17 of 100
# TrEpoch(017) -
#        acc    bmx  bmn     mse      spr     run
# 0  27.888  1.338  0.0  53.495  2062.08  55.557
# ValEpoch(017) -
#       acc   bmx  bmn   run
# 0  19.41  1.36  0.0  8.95
# *****
#  Epoch 18 of 100
# TrEpoch(018) -
#        acc    bmx  bmn     mse       spr    run
# 0  25.517  1.304  0.0  52.495  2035.742  54.53
# ValEpoch(018) -
#       acc    bmx  bmn    run
# 0  26.42  1.317  0.0  8.795
# *****
#  Epoch 19 of 100
# TrEpoch(019) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.942  1.315  0.0  52.167  2013.014  54.181
# ValEpoch(019) -
#       acc    bmx  bmn    run
# 0  26.07  1.239  0.0  8.764
# *****
#  Epoch 20 of 100
# TrEpoch(020) -
#       acc    bmx  bmn     mse       spr     run
# 0  26.89  1.273  0.0  51.946  1987.375  53.934
# ValEpoch(020) -
#       acc    bmx  bmn    run
# 0  26.41  1.302  0.0  8.747
# *****
#  Epoch 21 of 100
# TrEpoch(021) - l1 tensor(0.0380, grad_fn=<AddBackward0>)
# l1 tensor(0.0721, grad_fn=<AddBackward0>)
# l1 tensor(0.1088, grad_fn=<AddBackward0>)
# l1 tensor(0.1711, grad_fn=<AddBackward0>)
# l1 tensor(0.2528, grad_fn=<AddBackward0>)
# l1 tensor(0.3428, grad_fn=<AddBackward0>)
# l1 tensor(0.4461, grad_fn=<AddBackward0>)
# l1 tensor(0.5882, grad_fn=<AddBackward0>)
# l1 tensor(0.7407, grad_fn=<AddBackward0>)
# l1 tensor(0.9947, grad_fn=<AddBackward0>)
# sp_loss: 0.9946747422218323
#
#        acc    bmx  bmn     mse       spr     run
# 0  27.112  1.288  0.0  51.705  1965.168  53.671
# ValEpoch(021) -
#      acc    bmx  bmn    run
# 0  21.4  1.233  0.0  8.692
# *****
#  Epoch 22 of 100
# TrEpoch(022) -
#        acc    bmx  bmn     mse       spr    run
# 0  23.617  1.195  0.0  51.505  1944.471  53.45
# ValEpoch(022) -
#       acc    bmx  bmn    run
# 0  23.06  1.198  0.0  8.682
# *****
#  Epoch 23 of 100
# TrEpoch(023) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.548  1.209  0.0  51.326  1924.286  53.251
# ValEpoch(023) -
#       acc    bmx  bmn   run
# 0  21.58  1.143  0.0  8.64
# *****
#  Epoch 24 of 100
# TrEpoch(024) -
#        acc    bmx  bmn     mse       spr    run
# 0  25.137  1.155  0.0  51.145  1905.454  53.05
# ValEpoch(024) -
#      acc    bmx  bmn   run
# 0  19.3  1.164  0.0  8.62
# *****
#  Epoch 25 of 100
# TrEpoch(025) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.693  1.137  0.0  50.995  1888.587  52.884
# ValEpoch(025) -
#       acc    bmx  bmn    run
# 0  21.19  1.103  0.0  8.586
# *****
#  Epoch 26 of 100
# TrEpoch(026) - l1 tensor(0.0354, grad_fn=<AddBackward0>)
# l1 tensor(0.0699, grad_fn=<AddBackward0>)
# l1 tensor(0.1062, grad_fn=<AddBackward0>)
# l1 tensor(0.1661, grad_fn=<AddBackward0>)
# l1 tensor(0.2454, grad_fn=<AddBackward0>)
# l1 tensor(0.3309, grad_fn=<AddBackward0>)
# l1 tensor(0.4278, grad_fn=<AddBackward0>)
# l1 tensor(0.5576, grad_fn=<AddBackward0>)
# l1 tensor(0.7111, grad_fn=<AddBackward0>)
# l1 tensor(1.0026, grad_fn=<AddBackward0>)
# sp_loss: 1.0025520324707031
#        acc    bmx  bmn     mse       spr     run
# 0  26.633  1.113  0.0  50.537  1873.583  52.411
# ValEpoch(026) -
#       acc    bmx  bmn    run
# 0  21.72  1.088  0.0  8.457
# *****
#  Epoch 27 of 100
# TrEpoch(027) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.742  1.082  0.0  50.021  1857.908  51.879
# ValEpoch(027) -
#       acc    bmx  bmn    run
# 0  22.58  1.083  0.0  8.465
# *****
#  Epoch 28 of 100
# TrEpoch(028) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.663  1.097  0.0  49.883  1842.386  51.726
# ValEpoch(028) -
#       acc    bmx  bmn   run
# 0  22.69  1.073  0.0  8.44
# *****
#  Epoch 29 of 100
# TrEpoch(029) -
#        acc   bmx  bmn     mse       spr     run
# 0  21.932  1.09  0.0  49.014  1830.271  50.844
# ValEpoch(029) -
#       acc   bmx  bmn    run
# 0  24.94  1.02  0.0  8.228
# *****
#  Epoch 30 of 100
# TrEpoch(030) -
#        acc    bmx  bmn     mse       spr     run
# 0  16.448  1.033  0.0  48.678  1816.222  50.494
# ValEpoch(030) -
#       acc    bmx  bmn    run
# 0  22.64  0.977  0.0  8.224
# *****
#  Epoch 31 of 100
# TrEpoch(031) - l1 tensor(0.0361, grad_fn=<AddBackward0>)
# l1 tensor(0.0679, grad_fn=<AddBackward0>)
# l1 tensor(0.0989, grad_fn=<AddBackward0>)
# l1 tensor(0.1489, grad_fn=<AddBackward0>)
# l1 tensor(0.2184, grad_fn=<AddBackward0>)
# l1 tensor(0.2969, grad_fn=<AddBackward0>)
# l1 tensor(0.3922, grad_fn=<AddBackward0>)
# l1 tensor(0.5352, grad_fn=<AddBackward0>)
# l1 tensor(0.6998, grad_fn=<AddBackward0>)
# l1 tensor(0.9876, grad_fn=<AddBackward0>)
# sp_loss: 0.9875575304031372
#
#        acc   bmx  bmn     mse       spr     run
# 0  16.917  1.01  0.0  48.228  1802.878  50.031
# ValEpoch(031) -
#       acc    bmx  bmn   run
# 0  23.69  0.983  0.0  8.13
# *****
#  Epoch 32 of 100
# TrEpoch(032) -
#        acc   bmx  bmn     mse       spr     run
# 0  15.912  1.01  0.0  47.992  1791.628  49.783
# ValEpoch(032) -
#       acc    bmx  bmn    run
# 0  24.48  1.009  0.0  8.052
# *****
#  Epoch 33 of 100
# TrEpoch(033) -
#        acc    bmx  bmn     mse       spr     run
# 0  23.325  1.014  0.0  46.548  1782.535  48.331
# ValEpoch(033) -
#       acc    bmx  bmn    run
# 0  22.78  0.983  0.0  7.853
# *****
#  Epoch 34 of 100
# TrEpoch(034) -
#        acc    bmx  bmn     mse       spr     run
# 0  15.787  0.984  0.0  46.401  1771.061  48.172
# ValEpoch(034) -
#       acc    bmx  bmn    run
# 0  25.11  0.934  0.0  7.861
# *****
#  Epoch 35 of 100
# TrEpoch(035) -
#        acc    bmx  bmn     mse       spr     run
# 0  16.718  0.978  0.0  46.306  1759.621  48.065
# ValEpoch(035) -
#       acc    bmx  bmn    run
# 0  22.69  0.961  0.0  7.843
# *****
#  Epoch 36 of 100
# TrEpoch(036) - l1 tensor(0.0359, grad_fn=<AddBackward0>)
# l1 tensor(0.0645, grad_fn=<AddBackward0>)
# l1 tensor(0.0936, grad_fn=<AddBackward0>)
# l1 tensor(0.1399, grad_fn=<AddBackward0>)
# l1 tensor(0.2034, grad_fn=<AddBackward0>)
# l1 tensor(0.2747, grad_fn=<AddBackward0>)
# l1 tensor(0.3616, grad_fn=<AddBackward0>)
# l1 tensor(0.4899, grad_fn=<AddBackward0>)
# l1 tensor(0.6387, grad_fn=<AddBackward0>)
# l1 tensor(0.8824, grad_fn=<AddBackward0>)
# sp_loss: 0.8823638558387756
#
#        acc    bmx  bmn     mse       spr     run
# 0  16.703  0.991  0.0  46.254  1748.411  48.002
# ValEpoch(036) -
#       acc    bmx  bmn    run
# 0  24.56  0.969  0.0  7.838
# *****
#  Epoch 37 of 100
# TrEpoch(037) -
#        acc    bmx  bmn     mse       spr     run
# 0  15.488  0.959  0.0  46.126  1737.326  47.863
# ValEpoch(037) -
#       acc    bmx  bmn    run
# 0  24.92  0.917  0.0  7.803
# *****
#  Epoch 38 of 100
# TrEpoch(038) -
#        acc    bmx  bmn     mse       spr     run
# 0  25.118  0.962  0.0  46.048  1727.942  47.776
# ValEpoch(038) -
#      acc    bmx  bmn    run
# 0  21.4  0.926  0.0  7.811
# *****
#  Epoch 39 of 100
# TrEpoch(039) -
#        acc    bmx  bmn    mse      spr     run
# 0  15.707  0.908  0.0  45.95  1718.99  47.669
# ValEpoch(039) -
#       acc    bmx  bmn    run
# 0  24.45  0.905  0.0  7.791
# *****
#  Epoch 40 of 100
# TrEpoch(040) -
#        acc   bmx  bmn     mse       spr     run
# 0  18.913  0.93  0.0  45.909  1710.005  47.619
# ValEpoch(040) -
#      acc    bmx  bmn    run
# 0  21.4  0.884  0.0  7.786
# *****
#  Epoch 41 of 100
# TrEpoch(041) - l1 tensor(0.0368, grad_fn=<AddBackward0>)
# l1 tensor(0.0653, grad_fn=<AddBackward0>)
# l1 tensor(0.0922, grad_fn=<AddBackward0>)
# l1 tensor(0.1350, grad_fn=<AddBackward0>)
# l1 tensor(0.1947, grad_fn=<AddBackward0>)
# l1 tensor(0.2637, grad_fn=<AddBackward0>)
# l1 tensor(0.3496, grad_fn=<AddBackward0>)
# l1 tensor(0.4805, grad_fn=<AddBackward0>)
# l1 tensor(0.6330, grad_fn=<AddBackward0>)
# l1 tensor(0.9118, grad_fn=<AddBackward0>)
# sp_loss: 0.9117752313613892
#
#        acc    bmx  bmn     mse      spr    run
# 0  19.975  0.928  0.0  45.818  1701.82  47.52
# ValEpoch(041) -
#      acc    bmx  bmn    run
# 0  21.8  0.872  0.0  7.776
# *****
#  Epoch 42 of 100
# TrEpoch(042) -
#        acc    bmx  bmn     mse      spr     run
# 0  15.087  0.914  0.0  45.462  1694.63  47.156
# ValEpoch(042) -
#       acc    bmx  bmn    run
# 0  21.58  0.872  0.0  7.645
# *****
#  Epoch 43 of 100
# TrEpoch(043) -
#        acc    bmx  bmn     mse       spr    run
# 0  19.398  0.925  0.0  44.992  1688.188  46.68
# ValEpoch(043) -
#      acc    bmx  bmn    run
# 0  21.8  0.872  0.0  7.544
# *****
#  Epoch 44 of 100
# TrEpoch(044) -
#        acc    bmx  bmn     mse       spr    run
# 0  18.455  0.873  0.0  44.148  1682.112  45.83
# ValEpoch(044) -
#       acc    bmx  bmn    run
# 0  22.08  0.811  0.0  7.411
# *****
#  Epoch 45 of 100
# TrEpoch(045) -
#        acc    bmx  bmn     mse       spr     run
# 0  19.235  0.895  0.0  43.595  1675.857  45.271
# ValEpoch(045) -
#       acc   bmx  bmn    run
# 0  18.04  0.84  0.0  7.408
# *****
#  Epoch 46 of 100
# TrEpoch(046) - l1 tensor(0.0374, grad_fn=<AddBackward0>)
# l1 tensor(0.0656, grad_fn=<AddBackward0>)
# l1 tensor(0.0916, grad_fn=<AddBackward0>)
# l1 tensor(0.1324, grad_fn=<AddBackward0>)
# l1 tensor(0.1893, grad_fn=<AddBackward0>)
# l1 tensor(0.2560, grad_fn=<AddBackward0>)
# l1 tensor(0.3402, grad_fn=<AddBackward0>)
# l1 tensor(0.4672, grad_fn=<AddBackward0>)
# l1 tensor(0.6185, grad_fn=<AddBackward0>)
# l1 tensor(0.9124, grad_fn=<AddBackward0>)
# sp_loss: 0.9123827219009399
#
#        acc    bmx  bmn     mse       spr     run
# 0  16.335  0.871  0.0  43.502  1671.691  45.174
# ValEpoch(046) -
#       acc    bmx  bmn    run
# 0  18.38  0.832  0.0  7.383
# *****
#  Epoch 47 of 100
# TrEpoch(047) -
#        acc    bmx  bmn     mse       spr     run
# 0  20.923  0.892  0.0  43.455  1666.002  45.121
# ValEpoch(047) -
#       acc    bmx  bmn    run
# 0  20.06  0.836  0.0  7.385
# *****
#  Epoch 48 of 100
# TrEpoch(048) -
#        acc    bmx  bmn     mse       spr     run
# 0  20.317  0.869  0.0  43.356  1662.511  45.018
# ValEpoch(048) -
#       acc   bmx  bmn    run
# 0  18.64  0.85  0.0  7.367
# *****
#  Epoch 49 of 100
# TrEpoch(049) -
#        acc    bmx  bmn     mse      spr     run
# 0  19.687  0.862  0.0  42.714  1662.68  44.377
# ValEpoch(049) -
#       acc    bmx  bmn    run
# 0  23.44  0.812  0.0  7.232
# *****
#  Epoch 50 of 100
# TrEpoch(050) -
#        acc    bmx  bmn     mse       spr     run
# 0  17.718  0.861  0.0  42.038  1662.926  43.701
# ValEpoch(050) -
#       acc    bmx  bmn   run
# 0  23.98  0.806  0.0  7.13
# *****
#  Epoch 51 of 100
# TrEpoch(051) - l1 tensor(0.0375, grad_fn=<AddBackward0>)
# l1 tensor(0.0681, grad_fn=<AddBackward0>)
# l1 tensor(0.0964, grad_fn=<AddBackward0>)
# l1 tensor(0.1380, grad_fn=<AddBackward0>)
# l1 tensor(0.1953, grad_fn=<AddBackward0>)
# l1 tensor(0.2607, grad_fn=<AddBackward0>)
# l1 tensor(0.3417, grad_fn=<AddBackward0>)
# l1 tensor(0.4625, grad_fn=<AddBackward0>)
# l1 tensor(0.6135, grad_fn=<AddBackward0>)
# l1 tensor(0.9143, grad_fn=<AddBackward0>)
# sp_loss: 0.914312481880188
#
#       acc   bmx  bmn     mse       spr     run
# 0  24.44  0.87  0.0  41.768  1662.857  43.431
# ValEpoch(051) -
#       acc    bmx  bmn    run
# 0  24.33  0.806  0.0  7.083
# *****
#  Epoch 52 of 100
# TrEpoch(052) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.363  0.881  0.0  41.612  1662.746  43.274
# ValEpoch(052) -
#       acc  bmx  bmn    run
# 0  23.84  0.8  0.0  7.072
# *****
#  Epoch 53 of 100
# TrEpoch(053) -
#        acc    bmx  bmn     mse       spr     run
# 0  24.838  0.847  0.0  41.465  1660.644  43.126
# ValEpoch(053) -
#       acc    bmx  bmn    run
# 0  24.09  0.792  0.0  7.031
# *****
#  Epoch 54 of 100
# TrEpoch(054) -
#        acc    bmx  bmn     mse       spr     run
# 0  28.192  0.832  0.0  41.292  1659.631  42.951
# ValEpoch(054) -
#       acc    bmx  bmn    run
# 0  23.99  0.807  0.0  7.005
# *****
#  Epoch 55 of 100
# TrEpoch(055) -
#        acc    bmx  bmn     mse       spr     run
# 0  24.675  0.827  0.0  41.169  1655.447  42.825
# ValEpoch(055) -
#       acc    bmx  bmn    run
# 0  23.75  0.773  0.0  6.987
# *****
#  Epoch 56 of 100
# TrEpoch(056) - l1 tensor(0.0400, grad_fn=<AddBackward0>)
# l1 tensor(0.0680, grad_fn=<AddBackward0>)
# l1 tensor(0.0927, grad_fn=<AddBackward0>)
# l1 tensor(0.1320, grad_fn=<AddBackward0>)
# l1 tensor(0.1864, grad_fn=<AddBackward0>)
# l1 tensor(0.2494, grad_fn=<AddBackward0>)
# l1 tensor(0.3292, grad_fn=<AddBackward0>)
# l1 tensor(0.4562, grad_fn=<AddBackward0>)
# l1 tensor(0.6040, grad_fn=<AddBackward0>)
# l1 tensor(0.8584, grad_fn=<AddBackward0>)
# sp_loss: 0.8584169745445251
#
#        acc    bmx  bmn     mse       spr    run
# 0  25.005  0.855  0.0  41.038  1652.864  42.69
# ValEpoch(056) -
#       acc    bmx  bmn    run
# 0  24.44  0.764  0.0  6.984
# *****
#  Epoch 57 of 100
# TrEpoch(057) -
#        acc   bmx  bmn     mse       spr     run
# 0  25.048  0.82  0.0  40.894  1649.168  42.543
# ValEpoch(057) -
#       acc    bmx  bmn    run
# 0  27.77  0.783  0.0  6.941
# *****
#  Epoch 58 of 100
# TrEpoch(058) -
#      acc    bmx  bmn     mse       spr     run
# 0  19.2  0.813  0.0  40.756  1647.569  42.403
# ValEpoch(058) -
#       acc    bmx  bmn    run
# 0  27.97  0.748  0.0  6.914
# *****
#  Epoch 59 of 100
# TrEpoch(059) -
#        acc    bmx  bmn     mse       spr    run
# 0  23.272  0.811  0.0  40.585  1644.902  42.23
# ValEpoch(059) -
#       acc    bmx  bmn    run
# 0  28.65  0.761  0.0  6.894
# *****
#  Epoch 60 of 100
# TrEpoch(060) -
#        acc    bmx  bmn     mse       spr     run
# 0  23.513  0.797  0.0  40.423  1643.208  42.066
# ValEpoch(060) -
#       acc   bmx  bmn    run
# 0  28.62  0.75  0.0  6.869
# *****
#  Epoch 61 of 100
# TrEpoch(061) - l1 tensor(0.0401, grad_fn=<AddBackward0>)
# l1 tensor(0.0689, grad_fn=<AddBackward0>)
# l1 tensor(0.0949, grad_fn=<AddBackward0>)
# l1 tensor(0.1348, grad_fn=<AddBackward0>)
# l1 tensor(0.1888, grad_fn=<AddBackward0>)
# l1 tensor(0.2516, grad_fn=<AddBackward0>)
# l1 tensor(0.3292, grad_fn=<AddBackward0>)
# l1 tensor(0.4481, grad_fn=<AddBackward0>)
# l1 tensor(0.5932, grad_fn=<AddBackward0>)
# l1 tensor(0.8514, grad_fn=<AddBackward0>)
# sp_loss: 0.8514050245285034
#
#       acc    bmx  bmn     mse       spr     run
# 0  23.62  0.794  0.0  40.285  1639.089  41.924
# ValEpoch(061) -
#       acc    bmx  bmn   run
# 0  28.96  0.747  0.0  6.84
# *****
#  Epoch 62 of 100
# TrEpoch(062) -
#        acc    bmx  bmn     mse       spr     run
# 0  19.378  0.781  0.0  40.172  1635.231  41.807
# ValEpoch(062) -
#      acc    bmx  bmn    run
# 0  28.9  0.744  0.0  6.825
# *****
#  Epoch 63 of 100
# TrEpoch(063) -
#        acc    bmx  bmn    mse       spr     run
# 0  27.233  0.773  0.0  40.07  1632.159  41.702
# ValEpoch(063) -
#       acc    bmx  bmn    run
# 0  29.63  0.726  0.0  6.821
# *****
#  Epoch 64 of 100
# TrEpoch(064) -
#       acc   bmx  bmn     mse       spr     run
# 0  29.46  0.79  0.0  39.936  1629.091  41.565
# ValEpoch(064) -
#       acc    bmx  bmn    run
# 0  29.34  0.732  0.0  6.801
# *****
#  Epoch 65 of 100
# TrEpoch(065) -
#        acc    bmx  bmn    mse       spr     run
# 0  25.312  0.755  0.0  39.83  1624.239  41.454
# ValEpoch(065) -
#       acc    bmx  bmn    run
# 0  29.29  0.712  0.0  6.779
# *****
#  Epoch 66 of 100
# TrEpoch(066) - l1 tensor(0.0375, grad_fn=<AddBackward0>)
# l1 tensor(0.0704, grad_fn=<AddBackward0>)
# l1 tensor(0.1000, grad_fn=<AddBackward0>)
# l1 tensor(0.1439, grad_fn=<AddBackward0>)
# l1 tensor(0.1996, grad_fn=<AddBackward0>)
# l1 tensor(0.2627, grad_fn=<AddBackward0>)
# l1 tensor(0.3394, grad_fn=<AddBackward0>)
# l1 tensor(0.4467, grad_fn=<AddBackward0>)
# l1 tensor(0.5822, grad_fn=<AddBackward0>)
# l1 tensor(0.8867, grad_fn=<AddBackward0>)
# sp_loss: 0.8867244720458984
#
#        acc    bmx  bmn     mse       spr     run
# 0  27.068  0.764  0.0  39.759  1619.682  41.379
# ValEpoch(066) -
#       acc    bmx  bmn    run
# 0  29.61  0.702  0.0  6.777
# *****
#  Epoch 67 of 100
# TrEpoch(067) -
#        acc    bmx  bmn     mse       spr     run
# 0  28.105  0.752  0.0  39.695  1614.243  41.309
# ValEpoch(067) -
#       acc    bmx  bmn    run
# 0  29.67  0.715  0.0  6.754
# *****
#  Epoch 68 of 100
# TrEpoch(068) -
#        acc    bmx  bmn     mse       spr     run
# 0  23.185  0.754  0.0  39.606  1610.307  41.216
# ValEpoch(068) -
#       acc    bmx  bmn    run
# 0  27.43  0.685  0.0  6.747
# *****
#  Epoch 69 of 100
# TrEpoch(069) -
#        acc    bmx  bmn     mse       spr     run
# 0  28.358  0.738  0.0  39.491  1607.712  41.099
# ValEpoch(069) -
#       acc    bmx  bmn    run
# 0  27.67  0.695  0.0  6.729
# *****
#  Epoch 70 of 100
# TrEpoch(070) -
#        acc    bmx  bmn     mse       spr     run
# 0  28.463  0.744  0.0  39.433  1603.843  41.037
# ValEpoch(070) -
#       acc    bmx  bmn    run
# 0  29.76  0.708  0.0  6.713
# *****
#  Epoch 71 of 100
# TrEpoch(071) - l1 tensor(0.0398, grad_fn=<AddBackward0>)
# l1 tensor(0.0682, grad_fn=<AddBackward0>)
# l1 tensor(0.0944, grad_fn=<AddBackward0>)
# l1 tensor(0.1342, grad_fn=<AddBackward0>)
# l1 tensor(0.1862, grad_fn=<AddBackward0>)
# l1 tensor(0.2464, grad_fn=<AddBackward0>)
# l1 tensor(0.3198, grad_fn=<AddBackward0>)
# l1 tensor(0.4340, grad_fn=<AddBackward0>)
# l1 tensor(0.5695, grad_fn=<AddBackward0>)
# l1 tensor(0.8209, grad_fn=<AddBackward0>)
# sp_loss: 0.8208901882171631
#
#        acc    bmx  bmn     mse       spr     run
# 0  28.668  0.721  0.0  39.362  1600.743  40.963
# ValEpoch(071) -
#      acc    bmx  bmn    run
# 0  28.3  0.714  0.0  6.724
# *****
#  Epoch 72 of 100
# TrEpoch(072) -
#        acc    bmx  bmn     mse       spr     run
# 0  29.483  0.719  0.0  39.323  1596.437  40.919
# ValEpoch(072) -
#       acc    bmx  bmn    run
# 0  31.98  0.688  0.0  6.701
# *****
#  Epoch 73 of 100
# TrEpoch(073) -
#        acc    bmx  bmn     mse      spr     run
# 0  22.767  0.716  0.0  39.244  1593.35  40.837
# ValEpoch(073) -
#       acc    bmx  bmn   run
# 0  29.55  0.688  0.0  6.69
# *****
#  Epoch 74 of 100
# TrEpoch(074) -
#        acc    bmx  bmn     mse       spr     run
# 0  25.095  0.704  0.0  39.161  1589.833  40.751
# ValEpoch(074) -
#       acc    bmx  bmn    run
# 0  29.72  0.674  0.0  6.681
# *****
#  Epoch 75 of 100
# TrEpoch(075) -
#       acc    bmx  bmn     mse      spr     run
# 0  22.73  0.727  0.0  39.085  1586.66  40.671
# ValEpoch(075) -
#       acc    bmx  bmn    run
# 0  27.56  0.657  0.0  6.675
# *****
#  Epoch 76 of 100
# TrEpoch(076) - l1 tensor(0.0426, grad_fn=<AddBackward0>)
# l1 tensor(0.0729, grad_fn=<AddBackward0>)
# l1 tensor(0.0984, grad_fn=<AddBackward0>)
# l1 tensor(0.1372, grad_fn=<AddBackward0>)
# l1 tensor(0.1889, grad_fn=<AddBackward0>)
# l1 tensor(0.2492, grad_fn=<AddBackward0>)
# l1 tensor(0.3220, grad_fn=<AddBackward0>)
# l1 tensor(0.4344, grad_fn=<AddBackward0>)
# l1 tensor(0.5750, grad_fn=<AddBackward0>)
# l1 tensor(0.8566, grad_fn=<AddBackward0>)
# sp_loss: 0.8566453456878662
#
#       acc    bmx  bmn     mse       spr     run
# 0  25.35  0.702  0.0  39.023  1583.919  40.607
# ValEpoch(076) -
#       acc    bmx  bmn    run
# 0  30.31  0.654  0.0  6.662
# *****
#  Epoch 77 of 100
# TrEpoch(077) -
#        acc   bmx  bmn    mse       spr     run
# 0  31.833  0.71  0.0  38.94  1581.532  40.521
# ValEpoch(077) -
#       acc    bmx  bmn    run
# 0  29.73  0.673  0.0  6.674
# *****
#  Epoch 78 of 100
# TrEpoch(078) -
#        acc    bmx  bmn     mse       spr     run
# 0  29.987  0.703  0.0  38.855  1579.651  40.435
# ValEpoch(078) -
#       acc    bmx  bmn    run
# 0  30.08  0.636  0.0  6.659
# *****
#  Epoch 79 of 100
# TrEpoch(079) -
#        acc    bmx  bmn     mse       spr    run
# 0  30.232  0.694  0.0  38.793  1576.712  40.37
# ValEpoch(079) -
#       acc    bmx  bmn    run
# 0  30.29  0.676  0.0  6.617
# *****
#  Epoch 80 of 100
# TrEpoch(080) -
#        acc    bmx  bmn     mse      spr     run
# 0  30.225  0.688  0.0  38.708  1574.59  40.282
# ValEpoch(080) -
#       acc    bmx  bmn    run
# 0  28.36  0.661  0.0  6.597
# *****
#  Epoch 81 of 100
# TrEpoch(081) - l1 tensor(0.0417, grad_fn=<AddBackward0>)
# l1 tensor(0.0721, grad_fn=<AddBackward0>)
# l1 tensor(0.0983, grad_fn=<AddBackward0>)
# l1 tensor(0.1369, grad_fn=<AddBackward0>)
# l1 tensor(0.1872, grad_fn=<AddBackward0>)
# l1 tensor(0.2448, grad_fn=<AddBackward0>)
# l1 tensor(0.3151, grad_fn=<AddBackward0>)
# l1 tensor(0.4241, grad_fn=<AddBackward0>)
# l1 tensor(0.5633, grad_fn=<AddBackward0>)
# l1 tensor(0.8514, grad_fn=<AddBackward0>)
# sp_loss: 0.8513686656951904
#
#        acc    bmx  bmn     mse       spr     run
# 0  25.415  0.696  0.0  38.592  1571.686  40.164
# ValEpoch(081) -
#       acc    bmx  bmn    run
# 0  30.35  0.654  0.0  6.585
# *****
#  Epoch 82 of 100
# TrEpoch(082) -
#        acc    bmx  bmn     mse       spr     run
# 0  20.583  0.679  0.0  38.495  1572.448  40.068
# ValEpoch(082) -
#       acc    bmx  bmn    run
# 0  28.19  0.653  0.0  6.556
# *****
#  Epoch 83 of 100
# TrEpoch(083) -
#        acc    bmx  bmn   mse       spr     run
# 0  30.773  0.691  0.0  38.4  1571.477  39.972
# ValEpoch(083) -
#       acc    bmx  bmn    run
# 0  25.92  0.643  0.0  6.563
# *****
#  Epoch 84 of 100
# TrEpoch(084) -
#        acc    bmx  bmn     mse      spr    run
# 0  24.827  0.673  0.0  38.299  1571.34  39.87
# ValEpoch(084) -
#      acc    bmx  bmn    run
# 0  22.3  0.659  0.0  6.534
# *****
#  Epoch 85 of 100
# TrEpoch(085) -
#        acc    bmx  bmn     mse       spr     run
# 0  30.987  0.684  0.0  38.189  1569.718  39.758
# ValEpoch(085) -
#       acc    bmx  bmn    run
# 0  25.66  0.636  0.0  6.509
# *****
#  Epoch 86 of 100
# TrEpoch(086) - l1 tensor(0.0425, grad_fn=<AddBackward0>)
# l1 tensor(0.0728, grad_fn=<AddBackward0>)
# l1 tensor(0.1001, grad_fn=<AddBackward0>)
# l1 tensor(0.1397, grad_fn=<AddBackward0>)
# l1 tensor(0.1921, grad_fn=<AddBackward0>)
# l1 tensor(0.2509, grad_fn=<AddBackward0>)
# l1 tensor(0.3225, grad_fn=<AddBackward0>)
# l1 tensor(0.4308, grad_fn=<AddBackward0>)
# l1 tensor(0.5695, grad_fn=<AddBackward0>)
# l1 tensor(0.8492, grad_fn=<AddBackward0>)
# sp_loss: 0.849226713180542
#
#        acc    bmx  bmn     mse       spr     run
# 0  26.905  0.659  0.0  38.084  1568.278  39.652
# ValEpoch(086) -
#       acc    bmx  bmn  run
# 0  31.37  0.615  0.0  6.5
# *****
#  Epoch 87 of 100
# TrEpoch(087) -
#        acc    bmx  bmn    mse       spr     run
# 0  31.338  0.651  0.0  37.99  1567.752  39.558
# ValEpoch(087) -
#       acc    bmx  bmn    run
# 0  29.56  0.606  0.0  6.481
# *****
#  Epoch 88 of 100
# TrEpoch(088) -
#        acc    bmx  bmn     mse       spr     run
# 0  20.915  0.652  0.0  37.884  1567.017  39.451
# ValEpoch(088) -
#      acc    bmx  bmn    run
# 0  32.0  0.609  0.0  6.468
# *****
#  Epoch 89 of 100
# TrEpoch(089) -
#       acc    bmx  bmn     mse       spr     run
# 0  28.33  0.629  0.0  37.773  1565.784  39.339
# ValEpoch(089) -
#       acc    bmx  bmn    run
# 0  30.36  0.593  0.0  6.449
# *****
#  Epoch 90 of 100
# TrEpoch(090) -
#        acc    bmx  bmn     mse       spr     run
# 0  28.507  0.631  0.0  37.681  1564.727  39.246
# ValEpoch(090) -
#       acc    bmx  bmn    run
# 0  26.99  0.601  0.0  6.442
# *****
#  Epoch 91 of 100
# TrEpoch(091) - l1 tensor(0.0389, grad_fn=<AddBackward0>)
# l1 tensor(0.0678, grad_fn=<AddBackward0>)
# l1 tensor(0.0935, grad_fn=<AddBackward0>)
# l1 tensor(0.1321, grad_fn=<AddBackward0>)
# l1 tensor(0.1828, grad_fn=<AddBackward0>)
# l1 tensor(0.2395, grad_fn=<AddBackward0>)
# l1 tensor(0.3084, grad_fn=<AddBackward0>)
# l1 tensor(0.4108, grad_fn=<AddBackward0>)
# l1 tensor(0.5355, grad_fn=<AddBackward0>)
# l1 tensor(0.7715, grad_fn=<AddBackward0>)
# sp_loss: 0.7714865803718567
#
#       acc    bmx  bmn     mse       spr     run
# 0  26.42  0.629  0.0  37.568  1563.368  39.131
# ValEpoch(091) -
#       acc    bmx  bmn    run
# 0  26.88  0.603  0.0  6.422
# *****
#  Epoch 92 of 100
# TrEpoch(092) -
#        acc    bmx  bmn     mse       spr     run
# 0  25.803  0.635  0.0  37.493  1562.287  39.056
# ValEpoch(092) -
#      acc   bmx  bmn    run
# 0  24.8  0.59  0.0  6.398
# *****
#  Epoch 93 of 100
# TrEpoch(093) -
#        acc    bmx  bmn    mse       spr     run
# 0  28.487  0.624  0.0  37.38  1561.707  38.942
# ValEpoch(093) -
#       acc    bmx  bmn    run
# 0  27.26  0.575  0.0  6.405
# *****
#  Epoch 94 of 100
# TrEpoch(094) -
#        acc    bmx  bmn     mse       spr     run
# 0  28.928  0.619  0.0  37.298  1560.534  38.859
# ValEpoch(094) -
#       acc    bmx  bmn    run
# 0  24.17  0.562  0.0  6.365
# *****
#  Epoch 95 of 100
# TrEpoch(095) -
#       acc    bmx  bmn     mse       spr     run
# 0  24.73  0.603  0.0  37.197  1559.558  38.757
# ValEpoch(095) -
#       acc    bmx  bmn    run
# 0  21.62  0.525  0.0  6.359
# *****
#  Epoch 96 of 100
# TrEpoch(096) - l1 tensor(0.0453, grad_fn=<AddBackward0>)
# l1 tensor(0.0746, grad_fn=<AddBackward0>)
# l1 tensor(0.0998, grad_fn=<AddBackward0>)
# l1 tensor(0.1374, grad_fn=<AddBackward0>)
# l1 tensor(0.1871, grad_fn=<AddBackward0>)
# l1 tensor(0.2439, grad_fn=<AddBackward0>)
# l1 tensor(0.3106, grad_fn=<AddBackward0>)
# l1 tensor(0.4142, grad_fn=<AddBackward0>)
# l1 tensor(0.5453, grad_fn=<AddBackward0>)
# l1 tensor(0.8073, grad_fn=<AddBackward0>)
# sp_loss: 0.8073368072509766
#
#        acc    bmx  bmn   mse       spr     run
# 0  27.632  0.609  0.0  37.1  1558.866  38.659
# ValEpoch(096) -
#       acc   bmx  bmn    run
# 0  21.89  0.57  0.0  6.337
# *****
#  Epoch 97 of 100
# TrEpoch(097) -
#        acc    bmx  bmn     mse       spr     run
# 0  26.892  0.599  0.0  37.019  1557.684  38.577
# ValEpoch(097) -
#       acc    bmx  bmn    run
# 0  25.04  0.556  0.0  6.328
# *****
#  Epoch 98 of 100
# TrEpoch(098) -
#       acc    bmx  bmn     mse       spr     run
# 0  24.76  0.613  0.0  36.909  1557.404  38.466
# ValEpoch(098) -
#       acc    bmx  bmn    run
# 0  24.79  0.548  0.0  6.201
# *****
#  Epoch 99 of 100
# TrEpoch(099) -
#        acc    bmx  bmn     mse       spr     run
# 0  24.918  0.588  0.0  36.167  1556.836  37.724
# ValEpoch(099) -
#       acc    bmx  bmn    run
# 0  23.84  0.537  0.0  6.184
# 1.53e+02 minutes

# %%
print(result_df_tr_all)
# Out:
#        acc    bmx  bmn      mse       spr      run
# 0   10.340  3.569  0.0  198.533  2457.281  200.990
# 1   18.938  3.564  0.0  114.773  2574.492  117.347
# 2   20.305  2.683  0.0  102.260  2466.176  104.726
# 3   19.670  2.499  0.0   92.352  2412.836   94.764
# 4   23.177  2.160  0.0   75.472  2574.698   78.047
# 5   25.953  2.055  0.0   67.901  2545.863   70.447
# 6   28.560  2.031  0.0   63.970  2449.728   66.420
# 7   28.302  1.963  0.0   62.313  2371.121   64.684
# 8   26.335  1.835  0.0   61.034  2327.248   63.361
# 9   28.450  1.718  0.0   60.055  2286.423   62.342
# 10  29.287  1.616  0.0   58.706  2251.900   60.958
# 11  28.952  1.598  0.0   57.515  2219.898   59.735
# 12  20.335  1.563  0.0   56.886  2183.527   59.069
# 13  23.167  1.484  0.0   56.333  2150.861   58.484
# 14  24.813  1.454  0.0   55.731  2128.642   57.859
# 15  25.542  1.461  0.0   55.076  2110.468   57.187
# 16  27.237  1.396  0.0   54.503  2084.872   56.588
# 17  27.888  1.338  0.0   53.495  2062.080   55.557
# 18  25.517  1.304  0.0   52.495  2035.742   54.530
# 19  26.942  1.315  0.0   52.167  2013.014   54.181
# 20  26.890  1.273  0.0   51.946  1987.375   53.934
# 21  27.112  1.288  0.0   51.705  1965.168   53.671
# 22  23.617  1.195  0.0   51.505  1944.471   53.450
# 23  26.548  1.209  0.0   51.326  1924.286   53.251
# 24  25.137  1.155  0.0   51.145  1905.454   53.050
# 25  26.693  1.137  0.0   50.995  1888.587   52.884
# 26  26.633  1.113  0.0   50.537  1873.583   52.411
# 27  26.742  1.082  0.0   50.021  1857.908   51.879
# 28  26.663  1.097  0.0   49.883  1842.386   51.726
# 29  21.932  1.090  0.0   49.014  1830.271   50.844
# 30  16.448  1.033  0.0   48.678  1816.222   50.494
# 31  16.917  1.010  0.0   48.228  1802.878   50.031
# 32  15.912  1.010  0.0   47.992  1791.628   49.783
# 33  23.325  1.014  0.0   46.548  1782.535   48.331
# 34  15.787  0.984  0.0   46.401  1771.061   48.172
# 35  16.718  0.978  0.0   46.306  1759.621   48.065
# 36  16.703  0.991  0.0   46.254  1748.411   48.002
# 37  15.488  0.959  0.0   46.126  1737.326   47.863
# 38  25.118  0.962  0.0   46.048  1727.942   47.776
# 39  15.707  0.908  0.0   45.950  1718.990   47.669
# 40  18.913  0.930  0.0   45.909  1710.005   47.619
# 41  19.975  0.928  0.0   45.818  1701.820   47.520
# 42  15.087  0.914  0.0   45.462  1694.630   47.156
# 43  19.398  0.925  0.0   44.992  1688.188   46.680
# 44  18.455  0.873  0.0   44.148  1682.112   45.830
# 45  19.235  0.895  0.0   43.595  1675.857   45.271
# 46  16.335  0.871  0.0   43.502  1671.691   45.174
# 47  20.923  0.892  0.0   43.455  1666.002   45.121
# 48  20.317  0.869  0.0   43.356  1662.511   45.018
# 49  19.687  0.862  0.0   42.714  1662.680   44.377
# 50  17.718  0.861  0.0   42.038  1662.926   43.701
# 51  24.440  0.870  0.0   41.768  1662.857   43.431
# 52  26.363  0.881  0.0   41.612  1662.746   43.274
# 53  24.838  0.847  0.0   41.465  1660.644   43.126
# 54  28.192  0.832  0.0   41.292  1659.631   42.951
# 55  24.675  0.827  0.0   41.169  1655.447   42.825
# 56  25.005  0.855  0.0   41.038  1652.864   42.690
# 57  25.048  0.820  0.0   40.894  1649.168   42.543
# 58  19.200  0.813  0.0   40.756  1647.569   42.403
# 59  23.272  0.811  0.0   40.585  1644.902   42.230
# 60  23.513  0.797  0.0   40.423  1643.208   42.066
# 61  23.620  0.794  0.0   40.285  1639.089   41.924
# 62  19.378  0.781  0.0   40.172  1635.231   41.807
# 63  27.233  0.773  0.0   40.070  1632.159   41.702
# 64  29.460  0.790  0.0   39.936  1629.091   41.565
# 65  25.312  0.755  0.0   39.830  1624.239   41.454
# 66  27.068  0.764  0.0   39.759  1619.682   41.379
# 67  28.105  0.752  0.0   39.695  1614.243   41.309
# 68  23.185  0.754  0.0   39.606  1610.307   41.216
# 69  28.358  0.738  0.0   39.491  1607.712   41.099
# 70  28.463  0.744  0.0   39.433  1603.843   41.037
# 71  28.668  0.721  0.0   39.362  1600.743   40.963
# 72  29.483  0.719  0.0   39.323  1596.437   40.919
# 73  22.767  0.716  0.0   39.244  1593.350   40.837
# 74  25.095  0.704  0.0   39.161  1589.833   40.751
# 75  22.730  0.727  0.0   39.085  1586.660   40.671
# 76  25.350  0.702  0.0   39.023  1583.919   40.607
# 77  31.833  0.710  0.0   38.940  1581.532   40.521
# 78  29.987  0.703  0.0   38.855  1579.651   40.435
# 79  30.232  0.694  0.0   38.793  1576.712   40.370
# 80  30.225  0.688  0.0   38.708  1574.590   40.282
# 81  25.415  0.696  0.0   38.592  1571.686   40.164
# 82  20.583  0.679  0.0   38.495  1572.448   40.068
# 83  30.773  0.691  0.0   38.400  1571.477   39.972
# 84  24.827  0.673  0.0   38.299  1571.340   39.870
# 85  30.987  0.684  0.0   38.189  1569.718   39.758
# 86  26.905  0.659  0.0   38.084  1568.278   39.652
# 87  31.338  0.651  0.0   37.990  1567.752   39.558
# 88  20.915  0.652  0.0   37.884  1567.017   39.451
# 89  28.330  0.629  0.0   37.773  1565.784   39.339
# 90  28.507  0.631  0.0   37.681  1564.727   39.246
# 91  26.420  0.629  0.0   37.568  1563.368   39.131
# 92  25.803  0.635  0.0   37.493  1562.287   39.056
# 93  28.487  0.624  0.0   37.380  1561.707   38.942
# 94  28.928  0.619  0.0   37.298  1560.534   38.859
# 95  24.730  0.603  0.0   37.197  1559.558   38.757
# 96  27.632  0.609  0.0   37.100  1558.866   38.659
# 97  26.892  0.599  0.0   37.019  1557.684   38.577
# 98  24.760  0.613  0.0   36.909  1557.404   38.466
# 99  24.918  0.588  0.0   36.167  1556.836   37.724

# %%
print(result_df_va_all)
# Out:
#       acc    bmx  bmn     run
# 0    8.08  3.094  0.0  21.638
# 1   19.04  2.582  0.0  17.904
# 2   19.65  2.818  0.0  16.543
# 3   23.52  2.340  0.0  13.886
# 4   24.35  2.030  0.0  11.809
# 5   23.21  1.985  0.0  10.947
# 6   24.62  1.791  0.0  10.574
# 7   24.75  1.798  0.0  10.334
# 8   29.59  1.571  0.0  10.156
# 9   27.54  1.593  0.0  10.000
# 10  27.37  1.561  0.0   9.736
# 11  23.20  1.488  0.0   9.592
# 12  25.00  1.477  0.0   9.525
# 13  24.12  1.365  0.0   9.442
# 14  21.17  1.504  0.0   9.335
# 15  25.20  1.432  0.0   9.209
# 16  21.03  1.408  0.0   9.147
# 17  19.41  1.360  0.0   8.950
# 18  26.42  1.317  0.0   8.795
# 19  26.07  1.239  0.0   8.764
# 20  26.41  1.302  0.0   8.747
# 21  21.40  1.233  0.0   8.692
# 22  23.06  1.198  0.0   8.682
# 23  21.58  1.143  0.0   8.640
# 24  19.30  1.164  0.0   8.620
# 25  21.19  1.103  0.0   8.586
# 26  21.72  1.088  0.0   8.457
# 27  22.58  1.083  0.0   8.465
# 28  22.69  1.073  0.0   8.440
# 29  24.94  1.020  0.0   8.228
# 30  22.64  0.977  0.0   8.224
# 31  23.69  0.983  0.0   8.130
# 32  24.48  1.009  0.0   8.052
# 33  22.78  0.983  0.0   7.853
# 34  25.11  0.934  0.0   7.861
# 35  22.69  0.961  0.0   7.843
# 36  24.56  0.969  0.0   7.838
# 37  24.92  0.917  0.0   7.803
# 38  21.40  0.926  0.0   7.811
# 39  24.45  0.905  0.0   7.791
# 40  21.40  0.884  0.0   7.786
# 41  21.80  0.872  0.0   7.776
# 42  21.58  0.872  0.0   7.645
# 43  21.80  0.872  0.0   7.544
# 44  22.08  0.811  0.0   7.411
# 45  18.04  0.840  0.0   7.408
# 46  18.38  0.832  0.0   7.383
# 47  20.06  0.836  0.0   7.385
# 48  18.64  0.850  0.0   7.367
# 49  23.44  0.812  0.0   7.232
# 50  23.98  0.806  0.0   7.130
# 51  24.33  0.806  0.0   7.083
# 52  23.84  0.800  0.0   7.072
# 53  24.09  0.792  0.0   7.031
# 54  23.99  0.807  0.0   7.005
# 55  23.75  0.773  0.0   6.987
# 56  24.44  0.764  0.0   6.984
# 57  27.77  0.783  0.0   6.941
# 58  27.97  0.748  0.0   6.914
# 59  28.65  0.761  0.0   6.894
# 60  28.62  0.750  0.0   6.869
# 61  28.96  0.747  0.0   6.840
# 62  28.90  0.744  0.0   6.825
# 63  29.63  0.726  0.0   6.821
# 64  29.34  0.732  0.0   6.801
# 65  29.29  0.712  0.0   6.779
# 66  29.61  0.702  0.0   6.777
# 67  29.67  0.715  0.0   6.754
# 68  27.43  0.685  0.0   6.747
# 69  27.67  0.695  0.0   6.729
# 70  29.76  0.708  0.0   6.713
# 71  28.30  0.714  0.0   6.724
# 72  31.98  0.688  0.0   6.701
# 73  29.55  0.688  0.0   6.690
# 74  29.72  0.674  0.0   6.681
# 75  27.56  0.657  0.0   6.675
# 76  30.31  0.654  0.0   6.662
# 77  29.73  0.673  0.0   6.674
# 78  30.08  0.636  0.0   6.659
# 79  30.29  0.676  0.0   6.617
# 80  28.36  0.661  0.0   6.597
# 81  30.35  0.654  0.0   6.585
# 82  28.19  0.653  0.0   6.556
# 83  25.92  0.643  0.0   6.563
# 84  22.30  0.659  0.0   6.534
# 85  25.66  0.636  0.0   6.509
# 86  31.37  0.615  0.0   6.500
# 87  29.56  0.606  0.0   6.481
# 88  32.00  0.609  0.0   6.468
# 89  30.36  0.593  0.0   6.449
# 90  26.99  0.601  0.0   6.442
# 91  26.88  0.603  0.0   6.422
# 92  24.80  0.590  0.0   6.398
# 93  27.26  0.575  0.0   6.405
# 94  24.17  0.562  0.0   6.365
# 95  21.62  0.525  0.0   6.359
# 96  21.89  0.570  0.0   6.337
# 97  25.04  0.556  0.0   6.328
# 98  24.79  0.548  0.0   6.201
# 99  23.84  0.537  0.0   6.184
