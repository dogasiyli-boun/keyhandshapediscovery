# %%
import sys, importlib as impL
sys.path.insert(1,'/mnt/USB_HDD_1TB/GitHub/keyhandshapediscovery/vae_torch')
sys.path.insert(1,'/mnt/USB_HDD_1TB/GitHub/keyhandshapediscovery')
import vae_torch_model as vtm
import vae_torch as vt
#from data_classes import khs_dataset_v2
import vae_scripts as vs
import sae_torch as st
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import vae_utils as vu
# Out:
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
experiments_folder='/mnt/USB_HDD_1TB/GitHub/keyhandshapediscovery/experiments/FM'
exp_base_name='exp_conv_ae_simple_is28_cf'
ae_f_name_base='ae_ft_conv_ae_simple_is28.npy'

# %%
vu.plot_cf_compare(cf_int_arr=np.array([247,248]), 
                   data_log_keys = ['tr_te','te'], loss_key='bottleneck_act', 
                   max_act_ep=None, legend_loc='lower right',
                   experiments_folder=experiments_folder,
                   exp_base_name=exp_base_name, ae_f_name_base=ae_f_name_base)
# Out:
# 247 ,  tr_te  - log is loaded with len:  32
# 247 ,  te  - log is loaded with len:  32
# 247_tr_te_bottleneck_act [19.485, 19.106666666666666, 19.206666666666667]
# max(29.43),min(18.54)
# 247_te_bottleneck_act [21.82, 21.84, 21.92]
# max(30.13),min(18.72)
# 248 ,  tr_te  - log is loaded with len:  100
# 248 ,  te  - log is loaded with len:  100
# 248_tr_te_bottleneck_act [28.18, 30.6, 29.58]
# max(37.96),min(17.57)
# 248_te_bottleneck_act [33.19, 33.2, 33.0]
# max(33.40),min(11.18)

# %%
vu.plot_cf_compare(cf_int_arr=np.array([247,248]), 
                   data_log_keys = ['tr_te','te'], loss_key='bottleneck_kmeans', 
                   max_act_ep=None, legend_loc='lower right',
                   experiments_folder=experiments_folder,
                   exp_base_name=exp_base_name, ae_f_name_base=ae_f_name_base)
# Out:
# 247 ,  tr_te  - log is loaded with len:  32
# 247 ,  te  - log is loaded with len:  32
# 247_tr_te_bottleneck_kmeans [48.00666666666667, 48.14666666666667, 48.04833333333333]
# max(49.24),min(34.99)
# 247_te_bottleneck_kmeans [44.4, 43.16, 48.03]
# max(48.03),min(37.98)
# 248 ,  tr_te  - log is loaded with len:  100
# 248 ,  te  - log is loaded with len:  100
# 248_tr_te_bottleneck_kmeans [59.71666666666667, 56.818333333333335, 55.96]
# max(59.72),min(38.31)
# 248_te_bottleneck_kmeans [52.07, 51.92, 52.26]
# max(57.59),min(38.50)

# %%
import importlib as impL
impL.reload(vu)
cf_int_arr=np.array([247,248])
mul_before_plot=[-1/13000,1]
vu.plot_cf_compare(cf_int_arr=cf_int_arr, mul_before_plot=mul_before_plot,
                   data_log_keys = ['tr_te'], loss_key='sparsity', 
                   max_act_ep=None, legend_loc='upper right',
                   experiments_folder=experiments_folder,
                   exp_base_name=exp_base_name, ae_f_name_base=ae_f_name_base)
# Out:
# 247 ,  tr_te  - log is loaded with len:  32
# 247_tr_te_sparsity [-13196.028125472367, -13196.115970611572, -13196.303627453744]
# max(-12946.50),min(-13196.30)
# 248 ,  tr_te  - log is loaded with len:  100
# 248_tr_te_sparsity [158.88443613948766, 156.9172584131593, 154.99259200441884]
# max(1081.88),min(154.99)

# %%
import importlib as impL
impL.reload(vu)
cf_int_arr=np.array([247,248])
mul_before_plot=[1,1]
vu.plot_cf_compare(cf_int_arr=cf_int_arr, mul_before_plot=mul_before_plot,
                   data_log_keys = ['tr_te'], loss_key='reconstruction', 
                   max_act_ep=None, legend_loc='upper right',
                   experiments_folder=experiments_folder,
                   exp_base_name=exp_base_name, ae_f_name_base=ae_f_name_base)
# Out:
# 247 ,  tr_te  - log is loaded with len:  32
# 247_tr_te_reconstruction [44.82064609229565, 43.930577332153916, 43.71587978489697]
# max(105.07),min(43.72)
# 248 ,  tr_te  - log is loaded with len:  100
# 248_tr_te_reconstruction [33.76746636349708, 33.724786845967174, 33.7071746410802]
# max(98.59),min(33.71)

# %%
import importlib as impL
impL.reload(vu)
vu.plot_cf(cf_int=248, data_log_keys = ['tr_te','te'], k_loss_disp_list=['sparsity','bottleneck_act'], max_act_ep=None,select_id_type='last',
           plot_cnt = 5,                   
           experiments_folder=experiments_folder,
           exp_base_name=exp_base_name, ae_f_name_base=ae_f_name_base)
# Out:
# tr_te  - log is loaded with len:  100
# te  - log is loaded with len:  100
# skipping -  valid loss
# skipping -  reconstruction
# sparsity :
# skipping -  bottleneck_kmeans
# bottleneck_act :
# 99 5 [93 94 95 96 97]
# 0*/mnt/USB_HDD_1TB/GitHub/keyhandshapediscovery/experiments/FM/exp_conv_ae_simple_is28_cf248/btl_093_tr_va_.png*
# [Errno 2] No such file or directory: '/mnt/USB_HDD_1TB/GitHub/keyhandshapediscovery/experiments/FM/exp_conv_ae_simple_is28_cf248/btl_093_tr_va_.png'

# %%
impL.reload(vu)
z_fill_int=2
loss_key='reconstruction' # sparsity, bottleneck_kmeans, bottleneck_act
data_log_keys=['tr_te']  # ['tr_va', 'va', 'te']
legend_loc='upper right'
cf_int_arr=[247,248]
mul_before_plot=np.ones(np.shape(cf_int_arr),dtype=int)
vu.plot_cf_compare(cf_int_arr=cf_int_arr, 
                data_log_keys=data_log_keys, 
                mul_before_plot=mul_before_plot, 
                loss_key=loss_key, 
                max_act_ep=None,
                legend_loc=legend_loc, 
                experiments_folder=experiments_folder, ae_f_name_base=ae_f_name_base,
                exp_base_name=exp_base_name, 
                z_fill_int=z_fill_int)
# Out:
# 247 ,  tr_te  - log is loaded with len:  32
# 247_tr_te_reconstruction [44.82064609229565, 43.930577332153916, 43.71587978489697]
# max(105.07),min(43.72)
# 248 ,  tr_te  - log is loaded with len:  100
# 248_tr_te_reconstruction [33.76746636349708, 33.724786845967174, 33.7071746410802]
# max(98.59),min(33.71)
