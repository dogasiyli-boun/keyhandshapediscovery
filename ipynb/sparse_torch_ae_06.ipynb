# %% [markdown]
# Importing Modules

# %%
import torch
import torchvision
import torch.nn as nn
import matplotlib
import matplotlib.pyplot as plt
import torchvision.transforms as transforms
import torch.nn.functional as F
import torch.optim as optim
import os
import time
import numpy as np
import argparse
from torchvision import datasets
from torch.utils.data import DataLoader
from torchvision.utils import save_image
matplotlib.style.use('ggplot')
import sys, importlib as impL
sys.path.insert(1,'/mnt/USB_HDD_1TB/GitHub/keyhandshapediscovery')
import helperFuncs as funcH
import pandas as pd
# Out:
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/doga/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
def calc_bottleneck_acc(bottleneck_vec, lab_vec):
    pred_vec = np.argmax(bottleneck_vec.T, axis=0).T.squeeze()
    centroid_info_pdf = funcH.get_cluster_centroids(bottleneck_vec, pred_vec, kluster_centers=None, verbose=0)
    _confMat_preds, kluster2Classes, kr_pdf, weightedPurity, cnmxh_perc = funcH.countPredictionsForConfusionMat(lab_vec, pred_vec, centroid_info_pdf=centroid_info_pdf, labelNames=None)
    sampleCount = np.sum(np.sum(_confMat_preds))
    acc = 100 * np.sum(np.diag(_confMat_preds)) / sampleCount
    bmx, bmn = np.max(bottleneck_vec), np.min(bottleneck_vec)
    return acc, bmx, bmn

funcH.setPandasDisplayOpts()

# %% [markdown]
# Constructing the Argument Parsers

# %%
#ap = argparse.ArgumentParser()
#ap.add_argument('-e', '--epochs', type=int, default=10, help='number of epochs to train our network for')
#ap.add_argument('-l', '--reg_param', type=float, default=0.001, help='regularization parameter `lambda`')
#ap.add_argument('-sc', '--add_sparse', type=str, default='yes', help='whether to add sparsity contraint or not')
#args = vars(ap.parse_args())
epochs = 100  # args['epochs']
reg_param = 0.001  # args['reg_param']
add_sparsity = 'yes'  # args['add_sparse']
learning_rate = 1e-4
batch_size = 32
print(f"Add sparsity regularization: {add_sparsity}")
# Out:
# Add sparsity regularization: yes

# %% [markdown]
# here I will change the data loader per my need

# %%
# get the computation device
def get_device():
    return 'cuda:0' if torch.cuda.is_available() else 'cpu'
device = get_device()

# %%
# image transformations
transform = transforms.Compose([
    transforms.ToTensor(),
])

FOLDERS = {
    "data": '/mnt/USB_HDD_1TB/Datasets',
    "experiment": '/mnt/USB_HDD_1TB/GitHub/keyhandshapediscovery/experiments/SPARSE_TORCH/sparse_torch_ae_06',
}
FOLDERS["model_save"] = os.path.join(FOLDERS["experiment"], "model")
FOLDERS["decoder_image_path_tr"] = os.path.join(FOLDERS["experiment"], "output_images_tr")
FOLDERS["decoder_image_path_va"] = os.path.join(FOLDERS["experiment"], "output_images_va")
funcH.createDirIfNotExist(FOLDERS["model_save"])
funcH.createDirIfNotExist(FOLDERS["decoder_image_path_tr"])
funcH.createDirIfNotExist(FOLDERS["decoder_image_path_va"])

trainset = datasets.FashionMNIST(
    root=FOLDERS["data"],
    train=True, 
    download=True,
    transform=transform
)
testset = datasets.FashionMNIST(
    root=FOLDERS["data"],
    train=False,
    download=True,
    transform=transform
)
 
# trainloader
trainloader = DataLoader(
    trainset, 
    batch_size=batch_size,
    shuffle=True
)
#testloader
testloader = DataLoader(
    testset, 
    batch_size=batch_size, 
    shuffle=False
)

# %%
# define the autoencoder model
class SparseAutoencoder(nn.Module):
    def __init__(self, loss_type):
        super(SparseAutoencoder, self).__init__()
 
        # encoder
        self.enc1 = nn.Linear(in_features=784, out_features=256)
        self.enc2 = nn.Linear(in_features=256, out_features=128)
        self.enc3 = nn.Linear(in_features=128, out_features=64)
        self.enc4 = nn.Linear(in_features=64, out_features=32)
        self.enc5 = nn.Linear(in_features=32, out_features=16)
 
        # decoder 
        self.dec1 = nn.Linear(in_features=16, out_features=32)
        self.dec2 = nn.Linear(in_features=32, out_features=64)
        self.dec3 = nn.Linear(in_features=64, out_features=128)
        self.dec4 = nn.Linear(in_features=128, out_features=256)
        self.dec5 = nn.Linear(in_features=256, out_features=784)
        
        self.loss_type=loss_type
        self.device = get_device()
 
    def forward(self, x):
        # encoding
        x = F.relu(self.enc1(x))
        x = F.relu(self.enc2(x))
        x = F.relu(self.enc3(x))
        x = F.relu(self.enc4(x))
        bottleneck = F.relu(self.enc5(x))

        # decoding
        x = F.relu(self.dec1(bottleneck))
        x = F.relu(self.dec2(x))
        x = F.relu(self.dec3(x))
        x = F.relu(self.dec4(x))
        x = F.relu(self.dec5(x))
        return x, bottleneck
model = SparseAutoencoder(loss_type='kl').to(device)

# %%
# the loss function
criterion = nn.MSELoss()
# the optimizer
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# get the layers as a list
model_children = list(model.children())
[print(i) for i in model_children]
# Out:
# Linear(in_features=784, out_features=256, bias=True)
# Linear(in_features=256, out_features=128, bias=True)
# Linear(in_features=128, out_features=64, bias=True)
# Linear(in_features=64, out_features=32, bias=True)
# Linear(in_features=32, out_features=16, bias=True)
# Linear(in_features=16, out_features=32, bias=True)
# Linear(in_features=32, out_features=64, bias=True)
# Linear(in_features=64, out_features=128, bias=True)
# Linear(in_features=128, out_features=256, bias=True)
# Linear(in_features=256, out_features=784, bias=True)
# [None, None, None, None, None, None, None, None, None, None]

# %%
def loss_l1(bottleneck):
    return torch.mean(torch.abs(bottleneck))

def loss_l2(bottleneck):
    return torch.mean(torch.pow(bottleneck, torch.tensor(2.0).to(device))).sqrt()

def kl_divergence(bottleneck):
    rho = 0.05
    bottleneck = torch.mean(torch.sigmoid(bottleneck), 1)  # sigmoid because we need the probability distributions
    rho = torch.tensor([rho] * len(bottleneck)).to(device)
    loss_ret_1 = torch.nn.functional.kl_div(bottleneck, rho, reduction='batchmean')
    # torch.sum(rho * torch.log(rho / bottleneck) + (1 - rho) * torch.log((1 - rho) / (1 - bottleneck)))
    return loss_ret_1

# %%
# define the sparse loss function
def sparse_loss(autoencoder, images, print_info, loss_type):
    loss = 0
    values = images
    for i in range(len(model_children)):
        values = F.relu((model_children[i](values)))
        #if print_info:
            #print(i, ' shape=', values.shape)
        if loss_type=='l1':
            loss += loss_l1(values)
        if loss_type=='l2':
            loss += loss_l2(values)
        if loss_type=='kl':
            loss += kl_divergence(values)
        if print_info:
            print(loss_type,loss)
    return loss

# %%
def save_decoded_image(img, name):
    img = img.view(img.size(0), 1, 28, 28)
    save_image(img, name)

# define the training function
def fit(model, dataloader, epoch, print_losses_fit):
    print('TrEpoch({:03d}) - '.format(epoch), end='')
    model.train()
    running_loss = 0.0
    
    lab_vec = []
    bottleneck_vec = []
    sparsity_loss_sum = 0
    mse_sum = 0
       
    for data in dataloader:
        img, lb = data
        lab_vec.append(lb)
        
        img = img.to(device)
        img = img.view(img.size(0), -1)
        optimizer.zero_grad()
        outputs, bottleneck = model(img)
        bottleneck_vec.append(bottleneck)
        mse_loss = criterion(outputs, img)
        mse_sum += mse_loss.item()
        #if print_losses_fit:
            #print("mse_loss:", mse_loss.to('cpu'))
            #print("bottleneck:", bottleneck.to('cpu'))
        if add_sparsity == 'yes':
            sp_loss = sparse_loss(model, img, print_losses_fit, model.loss_type)
            sparsity_loss_sum += sp_loss.item()
            # add the sparsity penalty
            if print_losses_fit:
                print("sp_loss:", sparsity_loss_sum)
            loss = mse_loss - reg_param * sp_loss
        else:
            loss = mse_loss
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        print_losses_fit = False
    
    lab_vec = np.asarray(torch.cat(lab_vec).to(torch.device('cpu')))
    bottleneck_vec = np.asarray(torch.cat(bottleneck_vec).to(torch.device('cpu')).detach().numpy())
    acc, bmx, bmn = calc_bottleneck_acc(bottleneck_vec, lab_vec)
    #print("tr bottleneck accuracy=", acc, ", max=", bmx, ", min=", bmn, ", sparsity_loss_sum=", sparsity_loss_sum)
  
    result_df = pd.DataFrame(np.array([[acc, bmx, bmn, mse_sum, sparsity_loss_sum, running_loss]]), columns=['acc','bmx','bmn','mse','spr','run'])
    #print(df.iloc[0]['mse']) #'acc','bmx','bmn','mse','spr','run'
    print("\n",result_df)
    if epoch % 2 == 0:
        difn = os.path.join(FOLDERS["decoder_image_path_tr"], "train"+str(epoch).zfill(3)+".png")
        save_decoded_image(outputs.cpu().data, difn)
    return result_df

# %%
# define the validation function
def validate(model, dataloader, epoch, print_losses_fit):
    print('ValEpoch({:03d}) - '.format(epoch), end='')
    model.eval()
    running_loss = 0.0
    lab_vec = []
    bottleneck_vec = []
    with torch.no_grad():
        for data in dataloader:
            img, lb = data
            lab_vec.append(lb)
            img = img.to(device)
            img = img.view(img.size(0), -1)
            outputs, bottleneck = model(img)
            bottleneck_vec.append(bottleneck)
            loss = criterion(outputs, img)
            running_loss += loss.item()
    # save the reconstructed images every 5 epochs
    lab_vec = np.asarray(torch.cat(lab_vec).to(torch.device('cpu')))
    bottleneck_vec = np.asarray(torch.cat(bottleneck_vec).to(torch.device('cpu')).detach().numpy())
    acc, bmx, bmn = calc_bottleneck_acc(bottleneck_vec, lab_vec)

    result_df = pd.DataFrame(np.array([[acc, bmx, bmn, running_loss]]), columns=['acc','bmx','bmn','run'])
    print("\n",result_df)
    
    if epoch % 2 == 0:
        outputs = outputs.view(outputs.size(0), 1, 28, 28).cpu().data
        difn = os.path.join(FOLDERS["decoder_image_path_va"], "reconstruction"+str(epoch).zfill(3)+".png")
        save_image(outputs, difn)
    return result_df

# %%
# train and validate the autoencoder neural network
start = time.time()
print_losses_fit = True

train_loss = []
trn_spars_loss = []
trn_bot_acc = []
val_loss = []
val_bot_acc = []

result_df_tr_all = pd.DataFrame(columns=['acc','bmx','bmn','mse','spr','run'])
result_df_va_all = pd.DataFrame(columns=['acc','bmx','bmn','run'])

print("stae6 - lr 1e-4")

for epoch in range(epochs):
    print(f"*****\n Epoch {epoch} of {epochs}")
    result_df_tr = fit(model, trainloader, epoch, print_losses_fit)
    result_df_va = validate(model, testloader, epoch, print_losses_fit)
    print_losses_fit = epoch%5==0 and epoch>0
    result_df_tr_all = result_df_tr_all.append(result_df_tr, ignore_index=True)
    result_df_va_all = result_df_va_all.append(result_df_va, ignore_index=True)
    
end = time.time()
 
print(f"{(end-start)/60:.3} minutes")
# save the trained model

mofn = os.path.join(FOLDERS["model_save"], "sparse_ae_"+str(epoch).zfill(3)+".pth")
torch.save(model.state_dict(), mofn)
# Out:
# stae6 - lr 1e-4
# *****
#  Epoch 1 of 100
# TrEpoch(000) - kl tensor(-0.1759, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3511, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5262, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7015, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.8765, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.0518, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.2271, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4023, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.5774, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.7524, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.75235915184021
#
#        acc     bmx  bmn      mse       spr      run
# 0  16.822  31.481  0.0  150.672 -3417.219  154.089
# ValEpoch(000) -
#       acc    bmx  bmn     run
# 0  14.25  31.25  0.0  18.169
# *****
#  Epoch 2 of 100
# TrEpoch(001) - kl tensor(-0.1898, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3770, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5622, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7483, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9327, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1183, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.2999, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4801, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6586, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8363, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8363149166107178
#
#        acc     bmx  bmn      mse      spr      run
# 0  18.418  37.704  0.0  101.894 -3451.07  105.345
# ValEpoch(001) -
#       acc     bmx  bmn    run
# 0  17.52  35.992  0.0  15.53
# *****
#  Epoch 3 of 100
# TrEpoch(002) -
#       acc     bmx  bmn    mse       spr     run
# 0  13.13  41.888  0.0  83.85 -3464.002  87.314
# ValEpoch(002) -
#       acc     bmx  bmn     run
# 0  17.37  41.532  0.0  13.218
# *****
#  Epoch 4 of 100
# TrEpoch(003) -
#        acc     bmx  bmn     mse       spr     run
# 0  17.645  42.489  0.0  75.844 -3467.321  79.312
# ValEpoch(003) -
#      acc    bmx  bmn     run
# 0  17.7  42.67  0.0  12.123
# *****
#  Epoch 5 of 100
# TrEpoch(004) -
#       acc     bmx  bmn   mse       spr     run
# 0  17.64  44.134  0.0  71.3 -3468.729  74.769
# ValEpoch(004) -
#       acc     bmx  bmn     run
# 0  17.43  44.112  0.0  11.731
# *****
#  Epoch 6 of 100
# TrEpoch(005) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.952  47.107  0.0  67.448 -3470.906  70.919
# ValEpoch(005) -
#       acc     bmx  bmn     run
# 0  17.13  46.047  0.0  10.979
# *****
#  Epoch 7 of 100
# TrEpoch(006) - kl tensor(-0.1893, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3775, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5639, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7517, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9389, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1270, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3105, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4925, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6713, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8493, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8492746353149414
#
#        acc     bmx  bmn     mse       spr     run
# 0  16.697  48.202  0.0  64.615 -3473.077  68.088
# ValEpoch(006) -
#       acc     bmx  bmn    run
# 0  15.84  47.428  0.0  10.66
# *****
#  Epoch 8 of 100
# TrEpoch(007) -
#       acc    bmx  bmn     mse       spr    run
# 0  15.67  49.32  0.0  63.005 -3474.386  66.48
# ValEpoch(007) -
#       acc     bmx  bmn    run
# 0  15.81  47.965  0.0  10.42
# *****
#  Epoch 9 of 100
# TrEpoch(008) -
#        acc     bmx  bmn    mse       spr     run
# 0  15.027  49.679  0.0  60.06 -3474.755  63.535
# ValEpoch(008) -
#       acc    bmx  bmn    run
# 0  14.35  49.24  0.0  9.859
# *****
#  Epoch 10 of 100
# TrEpoch(009) -
#       acc    bmx  bmn     mse       spr     run
# 0  13.82  51.39  0.0  57.637 -3475.614  61.113
# ValEpoch(009) -
#       acc    bmx  bmn    run
# 0  13.62  50.88  0.0  9.495
# *****
#  Epoch 11 of 100
# TrEpoch(010) -
#       acc     bmx  bmn     mse       spr     run
# 0  12.75  52.259  0.0  56.285 -3476.353  59.761
# ValEpoch(010) -
#       acc     bmx  bmn    run
# 0  12.14  51.555  0.0  9.358
# *****
#  Epoch 12 of 100
# TrEpoch(011) - kl tensor(-0.1896, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3785, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5656, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7544, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9425, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1319, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3166, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4989, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6777, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8557, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8557422161102295
#
#        acc     bmx  bmn     mse       spr     run
# 0  12.207  52.748  0.0  55.542 -3476.645  59.019
# ValEpoch(011) -
#       acc     bmx  bmn    run
# 0  11.87  51.652  0.0  9.259
# *****
#  Epoch 13 of 100
# TrEpoch(012) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.868  53.516  0.0  54.667 -3476.632  58.144
# ValEpoch(012) -
#       acc     bmx  bmn   run
# 0  11.58  51.823  0.0  9.07
# *****
#  Epoch 14 of 100
# TrEpoch(013) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.667  53.646  0.0  53.916 -3476.634  57.393
# ValEpoch(013) -
#       acc     bmx  bmn    run
# 0  11.55  51.779  0.0  8.986
# *****
#  Epoch 15 of 100
# TrEpoch(014) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.463  54.048  0.0  51.954 -3476.897  55.431
# ValEpoch(014) -
#       acc     bmx  bmn    run
# 0  11.45  52.281  0.0  8.445
# *****
#  Epoch 16 of 100
# TrEpoch(015) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.057  54.681  0.0  49.717 -3477.869  53.195
# ValEpoch(015) -
#       acc     bmx  bmn    run
# 0  12.06  53.204  0.0  8.258
# *****
#  Epoch 17 of 100
# TrEpoch(016) - kl tensor(-0.1884, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3773, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5643, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7531, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9418, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1311, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3154, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4971, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6755, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8533, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.853344202041626
#
#       acc     bmx  bmn     mse       spr     run
# 0  12.31  55.212  0.0  48.982 -3478.584  52.461
# ValEpoch(016) -
#       acc     bmx  bmn    run
# 0  12.15  53.204  0.0  8.177
# *****
#  Epoch 18 of 100
# TrEpoch(017) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.393  54.975  0.0  47.888 -3478.888  51.367
# ValEpoch(017) -
#       acc     bmx  bmn    run
# 0  12.43  53.521  0.0  7.982
# *****
#  Epoch 19 of 100
# TrEpoch(018) -
#        acc     bmx  bmn    mse       spr     run
# 0  12.337  55.897  0.0  47.14 -3479.426  50.619
# ValEpoch(018) -
#      acc     bmx  bmn    run
# 0  12.3  53.318  0.0  7.849
# *****
#  Epoch 20 of 100
# TrEpoch(019) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.265  55.758  0.0  46.581 -3479.802  50.061
# ValEpoch(019) -
#       acc   bmx  bmn    run
# 0  12.16  53.1  0.0  7.779
# *****
#  Epoch 21 of 100
# TrEpoch(020) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.148  55.962  0.0  45.849 -3480.011  49.329
# ValEpoch(020) -
#       acc    bmx  bmn    run
# 0  11.94  53.38  0.0  7.564
# *****
#  Epoch 22 of 100
# TrEpoch(021) - kl tensor(-0.1880, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3777, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5646, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7536, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9431, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1328, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3176, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4993, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6777, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8560, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8559911251068115
#        acc     bmx  bmn     mse       spr     run
# 0  12.065  55.942  0.0  44.901 -3479.956  48.381
# ValEpoch(021) -
#       acc    bmx  bmn    run
# 0  12.12  53.35  0.0  7.511
# *****
#  Epoch 23 of 100
# TrEpoch(022) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.025  55.788  0.0  44.063 -3479.913  47.543
# ValEpoch(022) -
#       acc     bmx  bmn    run
# 0  11.86  53.813  0.0  7.371
# *****
#  Epoch 24 of 100
# TrEpoch(023) -
#       acc     bmx  bmn     mse       spr     run
# 0  11.98  55.254  0.0  43.526 -3479.599  47.006
# ValEpoch(023) -
#      acc     bmx  bmn    run
# 0  10.6  53.755  0.0  7.279
# *****
#  Epoch 25 of 100
# TrEpoch(024) -
#        acc     bmx  bmn     mse       spr    run
# 0  11.995  54.909  0.0  43.241 -3479.503  46.72
# ValEpoch(024) -
#       acc     bmx  bmn    run
# 0  11.94  53.559  0.0  7.246
# *****
#  Epoch 26 of 100
# TrEpoch(025) -
#       acc     bmx  bmn     mse       spr     run
# 0  12.01  54.919  0.0  42.963 -3479.228  46.443
# ValEpoch(025) -
#       acc     bmx  bmn    run
# 0  11.98  53.568  0.0  7.223
# *****
#  Epoch 27 of 100
# TrEpoch(026) - kl tensor(-0.1869, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3763, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5632, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7522, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9413, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1308, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3156, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4969, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6748, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8528, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.852774977684021
#
#        acc     bmx  bmn     mse       spr     run
# 0  12.063  54.799  0.0  42.363 -3478.777  45.841
# ValEpoch(026) -
#      acc     bmx  bmn    run
# 0  11.9  53.438  0.0  6.998
# *****
#  Epoch 28 of 100
# TrEpoch(027) -
#        acc     bmx  bmn     mse      spr     run
# 0  12.057  54.226  0.0  41.554 -3478.41  45.032
# ValEpoch(027) -
#       acc     bmx  bmn    run
# 0  10.59  53.396  0.0  6.973
# *****
#  Epoch 29 of 100
# TrEpoch(028) -
#       acc     bmx  bmn     mse       spr     run
# 0  12.03  54.226  0.0  41.343 -3478.111  44.822
# ValEpoch(028) -
#       acc     bmx  bmn    run
# 0  12.07  53.161  0.0  6.944
# *****
#  Epoch 30 of 100
# TrEpoch(029) -
#       acc     bmx  bmn    mse       spr     run
# 0  12.08  53.709  0.0  40.94 -3477.574  44.418
# ValEpoch(029) -
#       acc     bmx  bmn    run
# 0  12.06  52.438  0.0  6.799
# *****
#  Epoch 31 of 100
# TrEpoch(030) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.077  53.459  0.0  40.297 -3477.039  43.774
# ValEpoch(030) -
#       acc     bmx  bmn    run
# 0  11.93  52.292  0.0  6.765
# *****
#  Epoch 32 of 100
# TrEpoch(031) - kl tensor(-0.1865, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3758, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5630, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7521, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9418, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1315, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3163, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4978, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6760, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8538, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.853821039199829
#
#        acc    bmx  bmn     mse       spr     run
# 0  12.102  53.44  0.0  40.127 -3476.778  43.604
# ValEpoch(031) -
#       acc     bmx  bmn    run
# 0  12.02  51.806  0.0  6.744
# *****
#  Epoch 33 of 100
# TrEpoch(032) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.092  53.671  0.0  39.752 -3476.361  43.228
# ValEpoch(032) -
#       acc     bmx  bmn    run
# 0  11.91  52.431  0.0  6.661
# *****
#  Epoch 34 of 100
# TrEpoch(033) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.133  53.225  0.0  39.433 -3475.967  42.909
# ValEpoch(033) -
#       acc     bmx  bmn   run
# 0  11.89  52.358  0.0  6.64
# *****
#  Epoch 35 of 100
# TrEpoch(034) -
#        acc     bmx  bmn    mse       spr     run
# 0  12.133  52.523  0.0  39.28 -3475.648  42.755
# ValEpoch(034) -
#       acc     bmx  bmn    run
# 0  12.07  52.061  0.0  6.608
# *****
#  Epoch 36 of 100
# TrEpoch(035) -
#        acc    bmx  bmn     mse       spr     run
# 0  12.137  52.57  0.0  39.152 -3475.374  42.628
# ValEpoch(035) -
#       acc     bmx  bmn    run
# 0  12.03  51.538  0.0  6.586
# *****
#  Epoch 37 of 100
# TrEpoch(036) - kl tensor(-0.1856, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3747, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5615, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7504, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9400, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1294, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3138, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4949, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6730, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8509, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.850900411605835
#
#        acc     bmx  bmn     mse       spr    run
# 0  12.175  52.331  0.0  39.015 -3474.977  42.49
# ValEpoch(036) -
#       acc    bmx  bmn    run
# 0  11.96  51.49  0.0  6.575
# *****
#  Epoch 38 of 100
# TrEpoch(037) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.193  52.423  0.0  38.896 -3474.664  42.371
# ValEpoch(037) -
#      acc     bmx  bmn    run
# 0  12.2  51.456  0.0  6.545
# *****
#  Epoch 39 of 100
# TrEpoch(038) -
#      acc     bmx  bmn    mse       spr     run
# 0  12.2  52.686  0.0  38.68 -3474.548  42.155
# ValEpoch(038) -
#       acc     bmx  bmn    run
# 0  12.09  51.638  0.0  6.509
# *****
#  Epoch 40 of 100
# TrEpoch(039) -
#       acc     bmx  bmn     mse       spr     run
# 0  12.19  52.467  0.0  38.457 -3474.411  41.932
# ValEpoch(039) -
#       acc     bmx  bmn    run
# 0  12.11  51.604  0.0  6.471
# *****
#  Epoch 41 of 100
# TrEpoch(040) -
#        acc     bmx  bmn     mse       spr     run
# 0  12.127  52.685  0.0  38.245 -3474.394  41.719
# ValEpoch(040) -
#       acc     bmx  bmn   run
# 0  11.87  51.846  0.0  6.42
# *****
#  Epoch 42 of 100
# TrEpoch(041) - kl tensor(-0.1861, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3758, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5630, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7523, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9423, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1323, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3175, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4992, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6776, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8560, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8560105562210083
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.997  52.767  0.0  38.012 -3474.503  41.487
# ValEpoch(041) -
#       acc     bmx  bmn    run
# 0  11.85  52.173  0.0  6.388
# *****
#  Epoch 43 of 100
# TrEpoch(042) -
#       acc     bmx  bmn     mse       spr     run
# 0  11.97  52.964  0.0  37.798 -3474.408  41.273
# ValEpoch(042) -
#       acc     bmx  bmn    run
# 0  11.65  52.462  0.0  6.346
# *****
#  Epoch 44 of 100
# TrEpoch(043) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.795  53.418  0.0  37.572 -3474.496  41.046
# ValEpoch(043) -
#      acc     bmx  bmn    run
# 0  11.6  52.203  0.0  6.324
# *****
#  Epoch 45 of 100
# TrEpoch(044) -
#        acc     bmx  bmn     mse      spr     run
# 0  11.717  53.172  0.0  37.424 -3474.37  40.899
# ValEpoch(044) -
#      acc     bmx  bmn    run
# 0  11.6  51.937  0.0  6.313
# *****
#  Epoch 46 of 100
# TrEpoch(045) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.618  52.909  0.0  37.297 -3474.159  40.772
# ValEpoch(045) -
#       acc     bmx  bmn    run
# 0  11.55  51.704  0.0  6.301
# *****
#  Epoch 47 of 100
# TrEpoch(046) - kl tensor(-0.1845, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3737, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5608, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7498, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9396, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1290, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3132, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4938, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6718, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8496, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8495519161224365
#        acc     bmx  bmn     mse       spr     run
# 0  11.585  52.825  0.0  37.179 -3473.994  40.653
# ValEpoch(046) -
#      acc     bmx  bmn    run
# 0  11.2  51.795  0.0  6.283
# *****
#  Epoch 48 of 100
# TrEpoch(047) -
#        acc     bmx  bmn    mse       spr     run
# 0  11.542  52.609  0.0  37.07 -3473.657  40.543
# ValEpoch(047) -
#       acc     bmx  bmn    run
# 0  11.28  51.458  0.0  6.243
# *****
#  Epoch 49 of 100
# TrEpoch(048) -
#        acc     bmx  bmn    mse       spr     run
# 0  11.483  52.818  0.0  36.87 -3473.515  40.343
# ValEpoch(048) -
#       acc     bmx  bmn    run
# 0  11.17  51.005  0.0  6.208
# *****
#  Epoch 50 of 100
# TrEpoch(049) -
#        acc     bmx  bmn     mse      spr     run
# 0  11.403  52.682  0.0  36.683 -3473.26  40.157
# ValEpoch(049) -
#       acc     bmx  bmn    run
# 0  11.38  51.038  0.0  6.202
# *****
#  Epoch 51 of 100
# TrEpoch(050) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.373  52.632  0.0  36.577 -3473.122  40.051
# ValEpoch(050) -
#       acc     bmx  bmn    run
# 0  11.13  50.768  0.0  6.227
# *****
#  Epoch 52 of 100
# TrEpoch(051) - kl tensor(-0.1852, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3746, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5617, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7511, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9410, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1309, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3159, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4973, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6754, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8537, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.853720784187317
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.382  52.047  0.0  36.513 -3472.665  39.985
# ValEpoch(051) -
#       acc     bmx  bmn    run
# 0  11.14  50.671  0.0  6.167
# *****
#  Epoch 53 of 100
# TrEpoch(052) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.335  51.881  0.0  36.432 -3472.471  39.905
# ValEpoch(052) -
#       acc     bmx  bmn    run
# 0  11.05  49.912  0.0  6.156
# *****
#  Epoch 54 of 100
# TrEpoch(053) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.318  51.387  0.0  36.346 -3472.167  39.819
# ValEpoch(053) -
#      acc     bmx  bmn    run
# 0  11.3  49.708  0.0  6.161
# *****
#  Epoch 55 of 100
# TrEpoch(054) -
#        acc     bmx  bmn     mse       spr    run
# 0  11.338  51.021  0.0  36.268 -3472.038  39.74
# ValEpoch(054) -
#       acc     bmx  bmn    run
# 0  11.19  49.838  0.0  6.134
# *****
#  Epoch 56 of 100
# TrEpoch(055) -
#        acc    bmx  bmn     mse       spr     run
# 0  11.307  51.27  0.0  36.199 -3471.853  39.671
# ValEpoch(055) -
#       acc     bmx  bmn    run
# 0  11.14  49.348  0.0  6.145
# *****
#  Epoch 57 of 100
# TrEpoch(056) - kl tensor(-0.1845, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3735, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5606, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7497, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9398, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1295, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3141, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4950, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6731, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8512, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8512344360351562
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.295  50.959  0.0  36.124 -3471.514  39.595
# ValEpoch(056) -
#       acc   bmx  bmn    run
# 0  11.02  49.2  0.0  6.112
# *****
#  Epoch 58 of 100
# TrEpoch(057) -
#        acc     bmx  bmn     mse       spr    run
# 0  11.303  50.352  0.0  36.019 -3471.299  39.49
# ValEpoch(057) -
#       acc     bmx  bmn    run
# 0  10.99  49.104  0.0  6.092
# *****
#  Epoch 59 of 100
# TrEpoch(058) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.322  50.341  0.0  35.811 -3471.117  39.282
# ValEpoch(058) -
#       acc     bmx  bmn    run
# 0  11.06  48.946  0.0  6.015
# *****
#  Epoch 60 of 100
# TrEpoch(059) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.318  49.746  0.0  35.332 -3470.832  38.803
# ValEpoch(059) -
#       acc     bmx  bmn    run
# 0  11.07  48.676  0.0  5.996
# *****
#  Epoch 61 of 100
# TrEpoch(060) -
#       acc     bmx  bmn     mse       spr     run
# 0  11.32  49.859  0.0  35.262 -3470.582  38.733
# ValEpoch(060) -
#       acc     bmx  bmn    run
# 0  11.18  48.318  0.0  5.972
# *****
#  Epoch 62 of 100
# TrEpoch(061) - kl tensor(-0.1847, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3740, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5612, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7505, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9408, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1308, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3158, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4970, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6754, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8536, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.853609561920166
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.333  49.375  0.0  35.197 -3470.357  38.667
# ValEpoch(061) -
#       acc    bmx  bmn    run
# 0  11.02  47.87  0.0  5.981
# *****
#  Epoch 63 of 100
# TrEpoch(062) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.342  48.923  0.0  35.139 -3470.016  38.609
# ValEpoch(062) -
#       acc    bmx  bmn    run
# 0  11.23  48.08  0.0  5.955
# *****
#  Epoch 64 of 100
# TrEpoch(063) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.333  48.942  0.0  35.066 -3469.844  38.536
# ValEpoch(063) -
#       acc     bmx  bmn    run
# 0  10.96  47.697  0.0  5.948
# *****
#  Epoch 65 of 100
# TrEpoch(064) -
#       acc     bmx  bmn    mse       spr     run
# 0  11.35  48.753  0.0  35.01 -3469.631  38.479
# ValEpoch(064) -
#       acc     bmx  bmn    run
# 0  11.23  47.473  0.0  5.931
# *****
#  Epoch 66 of 100
# TrEpoch(065) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.383  48.387  0.0  34.935 -3469.495  38.404
# ValEpoch(065) -
#       acc     bmx  bmn    run
# 0  11.07  47.243  0.0  5.861
# *****
#  Epoch 67 of 100
# TrEpoch(066) - kl tensor(-0.1846, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3735, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5604, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7495, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9393, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1291, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3141, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4953, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6735, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8519, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.851946473121643
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.365  48.286  0.0  34.425 -3469.388  37.895
# ValEpoch(066) -
#       acc     bmx  bmn    run
# 0  11.12  46.881  0.0  5.833
# *****
#  Epoch 68 of 100
# TrEpoch(067) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.382  47.975  0.0  34.339 -3469.416  37.808
# ValEpoch(067) -
#       acc     bmx  bmn    run
# 0  11.15  46.752  0.0  5.814
# *****
#  Epoch 69 of 100
# TrEpoch(068) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.352  48.003  0.0  34.241 -3469.461  37.711
# ValEpoch(068) -
#       acc     bmx  bmn    run
# 0  11.15  46.517  0.0  5.807
# *****
#  Epoch 70 of 100
# TrEpoch(069) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.367  47.931  0.0  34.156 -3469.311  37.625
# ValEpoch(069) -
#       acc    bmx  bmn    run
# 0  11.45  46.07  0.0  5.797
# *****
#  Epoch 71 of 100
# TrEpoch(070) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.397  47.535  0.0  34.045 -3469.173  37.514
# ValEpoch(070) -
#       acc     bmx  bmn    run
# 0  11.17  46.378  0.0  5.771
# *****
#  Epoch 72 of 100
# TrEpoch(071) - kl tensor(-0.1840, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3730, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5600, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7491, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9397, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1295, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3142, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4949, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6730, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8513, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8512520790100098
#        acc     bmx  bmn     mse       spr     run
# 0  11.377  47.464  0.0  33.963 -3469.121  37.432
# ValEpoch(071) -
#       acc     bmx  bmn    run
# 0  11.17  46.165  0.0  5.776
# *****
#  Epoch 73 of 100
# TrEpoch(072) -
#        acc    bmx  bmn    mse      spr     run
# 0  11.365  47.22  0.0  33.88 -3468.95  37.349
# ValEpoch(072) -
#       acc     bmx  bmn    run
# 0  11.19  46.026  0.0  5.757
# *****
#  Epoch 74 of 100
# TrEpoch(073) -
#        acc     bmx  bmn    mse       spr     run
# 0  11.375  47.463  0.0  33.82 -3468.836  37.289
# ValEpoch(073) -
#       acc     bmx  bmn    run
# 0  11.21  45.665  0.0  5.734
# *****
#  Epoch 75 of 100
# TrEpoch(074) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.402  47.287  0.0  33.742 -3468.625  37.211
# ValEpoch(074) -
#       acc     bmx  bmn    run
# 0  11.41  45.455  0.0  5.724
# *****
#  Epoch 76 of 100
# TrEpoch(075) -
#       acc     bmx  bmn     mse       spr     run
# 0  11.39  47.395  0.0  33.672 -3468.585  37.141
# ValEpoch(075) -
#       acc     bmx  bmn    run
# 0  11.25  45.458  0.0  5.736
# *****
#  Epoch 77 of 100
# TrEpoch(076) - kl tensor(-0.1836, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3721, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5589, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7481, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9380, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1275, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3119, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4923, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6701, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8482, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8481853008270264
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.372  47.219  0.0  33.612 -3468.412  37.081
# ValEpoch(076) -
#       acc     bmx  bmn    run
# 0  11.19  45.312  0.0  5.716
# *****
#  Epoch 78 of 100
# TrEpoch(077) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.407  46.828  0.0  33.548 -3468.323  37.017
# ValEpoch(077) -
#       acc     bmx  bmn    run
# 0  11.36  45.029  0.0  5.709
# *****
#  Epoch 79 of 100
# TrEpoch(078) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.405  46.703  0.0  33.494 -3468.161  36.962
# ValEpoch(078) -
#       acc     bmx  bmn  run
# 0  11.38  44.837  0.0  5.7
# *****
#  Epoch 80 of 100
# TrEpoch(079) -
#        acc     bmx  bmn    mse       spr     run
# 0  11.403  46.607  0.0  33.44 -3468.118  36.908
# ValEpoch(079) -
#       acc    bmx  bmn    run
# 0  11.41  44.59  0.0  5.692
# *****
#  Epoch 81 of 100
# TrEpoch(080) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.458  46.269  0.0  33.384 -3467.895  36.852
# ValEpoch(080) -
#       acc     bmx  bmn    run
# 0  11.29  44.547  0.0  5.686
# *****
#  Epoch 82 of 100
# TrEpoch(081) - kl tensor(-0.1834, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3714, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5580, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7470, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9366, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1259, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3100, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4903, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6681, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8459, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8459234237670898
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.428  45.985  0.0  33.326 -3467.772  36.794
# ValEpoch(081) -
#       acc     bmx  bmn   run
# 0  11.39  44.287  0.0  5.68
# *****
#  Epoch 83 of 100
# TrEpoch(082) -
#        acc    bmx  bmn    mse       spr     run
# 0  11.445  46.01  0.0  33.28 -3467.639  36.748
# ValEpoch(082) -
#       acc     bmx  bmn    run
# 0  11.25  44.216  0.0  5.667
# *****
#  Epoch 84 of 100
# TrEpoch(083) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.418  46.258  0.0  33.216 -3467.703  36.684
# ValEpoch(083) -
#       acc     bmx  bmn    run
# 0  11.35  44.541  0.0  5.658
# *****
#  Epoch 85 of 100
# TrEpoch(084) -
#       acc     bmx  bmn     mse      spr     run
# 0  11.44  46.049  0.0  33.161 -3467.59  36.629
# ValEpoch(084) -
#       acc     bmx  bmn    run
# 0  11.39  44.252  0.0  5.646
# *****
#  Epoch 86 of 100
# TrEpoch(085) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.443  45.888  0.0  33.097 -3467.581  36.565
# ValEpoch(085) -
#       acc    bmx  bmn    run
# 0  11.23  44.09  0.0  5.629
# *****
#  Epoch 87 of 100
# TrEpoch(086) - kl tensor(-0.1834, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3715, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5583, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7473, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9375, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1267, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3109, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4914, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6694, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8473, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.847290277481079
#
#        acc     bmx  bmn     mse       spr    run
# 0  11.458  45.824  0.0  33.022 -3467.722  36.49
# ValEpoch(086) -
#       acc     bmx  bmn    run
# 0  11.21  44.189  0.0  5.627
# *****
#  Epoch 88 of 100
# TrEpoch(087) -
#        acc    bmx  bmn     mse       spr   run
# 0  11.405  45.81  0.0  32.932 -3468.033  36.4
# ValEpoch(087) -
#       acc    bmx  bmn    run
# 0  11.36  44.41  0.0  5.623
# *****
#  Epoch 89 of 100
# TrEpoch(088) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.392  46.043  0.0  32.858 -3468.223  36.326
# ValEpoch(088) -
#      acc     bmx  bmn    run
# 0  11.2  43.919  0.0  5.588
# *****
#  Epoch 90 of 100
# TrEpoch(089) -
#        acc     bmx  bmn     mse       spr    run
# 0  11.395  46.112  0.0  32.772 -3468.327  36.24
# ValEpoch(089) -
#       acc     bmx  bmn    run
# 0  11.26  44.351  0.0  5.578
# *****
#  Epoch 91 of 100
# TrEpoch(090) -
#        acc     bmx  bmn     mse       spr    run
# 0  11.337  45.623  0.0  32.701 -3468.379  36.17
# ValEpoch(090) -
#       acc     bmx  bmn    run
# 0  11.24  44.412  0.0  5.575
# *****
#  Epoch 92 of 100
# TrEpoch(091) - kl tensor(-0.1832, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3714, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5582, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7474, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9379, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1273, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3114, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4917, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6695, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8474, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8474278450012207
#
#        acc     bmx  bmn     mse       spr     run
# 0  11.353  45.684  0.0  32.638 -3468.379  36.106
# ValEpoch(091) -
#       acc     bmx  bmn    run
# 0  11.11  44.157  0.0  5.559
# *****
#  Epoch 93 of 100
# TrEpoch(092) -
#       acc     bmx  bmn     mse       spr     run
# 0  11.33  45.914  0.0  32.577 -3468.291  36.045
# ValEpoch(092) -
#       acc     bmx  bmn    run
# 0  11.18  44.139  0.0  5.554
# *****
#  Epoch 94 of 100
# TrEpoch(093) -
#        acc    bmx  bmn     mse      spr     run
# 0  11.295  45.74  0.0  32.513 -3468.19  35.981
# ValEpoch(093) -
#       acc     bmx  bmn    run
# 0  11.26  43.814  0.0  5.548
# *****
#  Epoch 95 of 100
# TrEpoch(094) -
#        acc     bmx  bmn     mse      spr     run
# 0  11.317  45.874  0.0  32.464 -3468.06  35.932
# ValEpoch(094) -
#       acc     bmx  bmn    run
# 0  11.14  43.863  0.0  5.528
# *****
#  Epoch 96 of 100
# TrEpoch(095) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.295  45.581  0.0  32.405 -3467.981  35.873
# ValEpoch(095) -
#       acc     bmx  bmn   run
# 0  11.19  43.596  0.0  5.53
# *****
#  Epoch 97 of 100
# TrEpoch(096) - kl tensor(-0.1836, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.3724, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.5595, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.7490, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-0.9402, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.1301, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.3147, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.4950, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.6730, device='cuda:0', grad_fn=<AddBackward0>)
# kl tensor(-1.8512, device='cuda:0', grad_fn=<AddBackward0>)
# sp_loss: -1.8512076139450073
#       acc    bmx  bmn     mse       spr     run
# 0  11.32  45.25  0.0  32.363 -3467.771  35.831
# ValEpoch(096) -
#       acc     bmx  bmn   run
# 0  11.13  43.387  0.0  5.53
# *****
#  Epoch 98 of 100
# TrEpoch(097) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.255  45.115  0.0  32.309 -3467.714  35.776
# ValEpoch(097) -
#       acc     bmx  bmn    run
# 0  11.12  43.446  0.0  5.511
# *****
#  Epoch 99 of 100
# TrEpoch(098) -
#        acc     bmx  bmn     mse      spr     run
# 0  11.262  44.998  0.0  32.272 -3467.47  35.739
# ValEpoch(098) -
#       acc     bmx  bmn    run
# 0  10.98  43.022  0.0  5.495
# *****
#  Epoch 100 of 100
# TrEpoch(099) -
#        acc     bmx  bmn     mse       spr     run
# 0  11.232  45.242  0.0  32.227 -3467.317  35.694
# ValEpoch(099) -
#       acc     bmx  bmn    run
# 0  10.98  43.017  0.0  5.491
# 33.9 minutes

# %%
print(result_df_tr_all)
# Out:
#        acc     bmx  bmn      mse       spr      run
# 0   16.822  31.481  0.0  150.672 -3417.219  154.089
# 1   18.418  37.704  0.0  101.894 -3451.070  105.345
# 2   13.130  41.888  0.0   83.850 -3464.002   87.314
# 3   17.645  42.489  0.0   75.844 -3467.321   79.312
# 4   17.640  44.134  0.0   71.300 -3468.729   74.769
# 5   12.952  47.107  0.0   67.448 -3470.906   70.919
# 6   16.697  48.202  0.0   64.615 -3473.077   68.088
# 7   15.670  49.320  0.0   63.005 -3474.386   66.480
# 8   15.027  49.679  0.0   60.060 -3474.755   63.535
# 9   13.820  51.390  0.0   57.637 -3475.614   61.113
# 10  12.750  52.259  0.0   56.285 -3476.353   59.761
# 11  12.207  52.748  0.0   55.542 -3476.645   59.019
# 12  11.868  53.516  0.0   54.667 -3476.632   58.144
# 13  11.667  53.646  0.0   53.916 -3476.634   57.393
# 14  11.463  54.048  0.0   51.954 -3476.897   55.431
# 15  11.057  54.681  0.0   49.717 -3477.869   53.195
# 16  12.310  55.212  0.0   48.982 -3478.584   52.461
# 17  12.393  54.975  0.0   47.888 -3478.888   51.367
# 18  12.337  55.897  0.0   47.140 -3479.426   50.619
# 19  12.265  55.758  0.0   46.581 -3479.802   50.061
# 20  12.148  55.962  0.0   45.849 -3480.011   49.329
# 21  12.065  55.942  0.0   44.901 -3479.956   48.381
# 22  12.025  55.788  0.0   44.063 -3479.913   47.543
# 23  11.980  55.254  0.0   43.526 -3479.599   47.006
# 24  11.995  54.909  0.0   43.241 -3479.503   46.720
# 25  12.010  54.919  0.0   42.963 -3479.228   46.443
# 26  12.063  54.799  0.0   42.363 -3478.777   45.841
# 27  12.057  54.226  0.0   41.554 -3478.410   45.032
# 28  12.030  54.226  0.0   41.343 -3478.111   44.822
# 29  12.080  53.709  0.0   40.940 -3477.574   44.418
# 30  12.077  53.459  0.0   40.297 -3477.039   43.774
# 31  12.102  53.440  0.0   40.127 -3476.778   43.604
# 32  12.092  53.671  0.0   39.752 -3476.361   43.228
# 33  12.133  53.225  0.0   39.433 -3475.967   42.909
# 34  12.133  52.523  0.0   39.280 -3475.648   42.755
# 35  12.137  52.570  0.0   39.152 -3475.374   42.628
# 36  12.175  52.331  0.0   39.015 -3474.977   42.490
# 37  12.193  52.423  0.0   38.896 -3474.664   42.371
# 38  12.200  52.686  0.0   38.680 -3474.548   42.155
# 39  12.190  52.467  0.0   38.457 -3474.411   41.932
# 40  12.127  52.685  0.0   38.245 -3474.394   41.719
# 41  11.997  52.767  0.0   38.012 -3474.503   41.487
# 42  11.970  52.964  0.0   37.798 -3474.408   41.273
# 43  11.795  53.418  0.0   37.572 -3474.496   41.046
# 44  11.717  53.172  0.0   37.424 -3474.370   40.899
# 45  11.618  52.909  0.0   37.297 -3474.159   40.772
# 46  11.585  52.825  0.0   37.179 -3473.994   40.653
# 47  11.542  52.609  0.0   37.070 -3473.657   40.543
# 48  11.483  52.818  0.0   36.870 -3473.515   40.343
# 49  11.403  52.682  0.0   36.683 -3473.260   40.157
# 50  11.373  52.632  0.0   36.577 -3473.122   40.051
# 51  11.382  52.047  0.0   36.513 -3472.665   39.985
# 52  11.335  51.881  0.0   36.432 -3472.471   39.905
# 53  11.318  51.387  0.0   36.346 -3472.167   39.819
# 54  11.338  51.021  0.0   36.268 -3472.038   39.740
# 55  11.307  51.270  0.0   36.199 -3471.853   39.671
# 56  11.295  50.959  0.0   36.124 -3471.514   39.595
# 57  11.303  50.352  0.0   36.019 -3471.299   39.490
# 58  11.322  50.341  0.0   35.811 -3471.117   39.282
# 59  11.318  49.746  0.0   35.332 -3470.832   38.803
# 60  11.320  49.859  0.0   35.262 -3470.582   38.733
# 61  11.333  49.375  0.0   35.197 -3470.357   38.667
# 62  11.342  48.923  0.0   35.139 -3470.016   38.609
# 63  11.333  48.942  0.0   35.066 -3469.844   38.536
# 64  11.350  48.753  0.0   35.010 -3469.631   38.479
# 65  11.383  48.387  0.0   34.935 -3469.495   38.404
# 66  11.365  48.286  0.0   34.425 -3469.388   37.895
# 67  11.382  47.975  0.0   34.339 -3469.416   37.808
# 68  11.352  48.003  0.0   34.241 -3469.461   37.711
# 69  11.367  47.931  0.0   34.156 -3469.311   37.625
# 70  11.397  47.535  0.0   34.045 -3469.173   37.514
# 71  11.377  47.464  0.0   33.963 -3469.121   37.432
# 72  11.365  47.220  0.0   33.880 -3468.950   37.349
# 73  11.375  47.463  0.0   33.820 -3468.836   37.289
# 74  11.402  47.287  0.0   33.742 -3468.625   37.211
# 75  11.390  47.395  0.0   33.672 -3468.585   37.141
# 76  11.372  47.219  0.0   33.612 -3468.412   37.081
# 77  11.407  46.828  0.0   33.548 -3468.323   37.017
# 78  11.405  46.703  0.0   33.494 -3468.161   36.962
# 79  11.403  46.607  0.0   33.440 -3468.118   36.908
# 80  11.458  46.269  0.0   33.384 -3467.895   36.852
# 81  11.428  45.985  0.0   33.326 -3467.772   36.794
# 82  11.445  46.010  0.0   33.280 -3467.639   36.748
# 83  11.418  46.258  0.0   33.216 -3467.703   36.684
# 84  11.440  46.049  0.0   33.161 -3467.590   36.629
# 85  11.443  45.888  0.0   33.097 -3467.581   36.565
# 86  11.458  45.824  0.0   33.022 -3467.722   36.490
# 87  11.405  45.810  0.0   32.932 -3468.033   36.400
# 88  11.392  46.043  0.0   32.858 -3468.223   36.326
# 89  11.395  46.112  0.0   32.772 -3468.327   36.240
# 90  11.337  45.623  0.0   32.701 -3468.379   36.170
# 91  11.353  45.684  0.0   32.638 -3468.379   36.106
# 92  11.330  45.914  0.0   32.577 -3468.291   36.045
# 93  11.295  45.740  0.0   32.513 -3468.190   35.981
# 94  11.317  45.874  0.0   32.464 -3468.060   35.932
# 95  11.295  45.581  0.0   32.405 -3467.981   35.873
# 96  11.320  45.250  0.0   32.363 -3467.771   35.831
# 97  11.255  45.115  0.0   32.309 -3467.714   35.776
# 98  11.262  44.998  0.0   32.272 -3467.470   35.739
# 99  11.232  45.242  0.0   32.227 -3467.317   35.694

# %%
print(result_df_va_all)
# Out:
#       acc     bmx  bmn     run
# 0   14.25  31.250  0.0  18.169
# 1   17.52  35.992  0.0  15.530
# 2   17.37  41.532  0.0  13.218
# 3   17.70  42.670  0.0  12.123
# 4   17.43  44.112  0.0  11.731
# 5   17.13  46.047  0.0  10.979
# 6   15.84  47.428  0.0  10.660
# 7   15.81  47.965  0.0  10.420
# 8   14.35  49.240  0.0   9.859
# 9   13.62  50.880  0.0   9.495
# 10  12.14  51.555  0.0   9.358
# 11  11.87  51.652  0.0   9.259
# 12  11.58  51.823  0.0   9.070
# 13  11.55  51.779  0.0   8.986
# 14  11.45  52.281  0.0   8.445
# 15  12.06  53.204  0.0   8.258
# 16  12.15  53.204  0.0   8.177
# 17  12.43  53.521  0.0   7.982
# 18  12.30  53.318  0.0   7.849
# 19  12.16  53.100  0.0   7.779
# 20  11.94  53.380  0.0   7.564
# 21  12.12  53.350  0.0   7.511
# 22  11.86  53.813  0.0   7.371
# 23  10.60  53.755  0.0   7.279
# 24  11.94  53.559  0.0   7.246
# 25  11.98  53.568  0.0   7.223
# 26  11.90  53.438  0.0   6.998
# 27  10.59  53.396  0.0   6.973
# 28  12.07  53.161  0.0   6.944
# 29  12.06  52.438  0.0   6.799
# 30  11.93  52.292  0.0   6.765
# 31  12.02  51.806  0.0   6.744
# 32  11.91  52.431  0.0   6.661
# 33  11.89  52.358  0.0   6.640
# 34  12.07  52.061  0.0   6.608
# 35  12.03  51.538  0.0   6.586
# 36  11.96  51.490  0.0   6.575
# 37  12.20  51.456  0.0   6.545
# 38  12.09  51.638  0.0   6.509
# 39  12.11  51.604  0.0   6.471
# 40  11.87  51.846  0.0   6.420
# 41  11.85  52.173  0.0   6.388
# 42  11.65  52.462  0.0   6.346
# 43  11.60  52.203  0.0   6.324
# 44  11.60  51.937  0.0   6.313
# 45  11.55  51.704  0.0   6.301
# 46  11.20  51.795  0.0   6.283
# 47  11.28  51.458  0.0   6.243
# 48  11.17  51.005  0.0   6.208
# 49  11.38  51.038  0.0   6.202
# 50  11.13  50.768  0.0   6.227
# 51  11.14  50.671  0.0   6.167
# 52  11.05  49.912  0.0   6.156
# 53  11.30  49.708  0.0   6.161
# 54  11.19  49.838  0.0   6.134
# 55  11.14  49.348  0.0   6.145
# 56  11.02  49.200  0.0   6.112
# 57  10.99  49.104  0.0   6.092
# 58  11.06  48.946  0.0   6.015
# 59  11.07  48.676  0.0   5.996
# 60  11.18  48.318  0.0   5.972
# 61  11.02  47.870  0.0   5.981
# 62  11.23  48.080  0.0   5.955
# 63  10.96  47.697  0.0   5.948
# 64  11.23  47.473  0.0   5.931
# 65  11.07  47.243  0.0   5.861
# 66  11.12  46.881  0.0   5.833
# 67  11.15  46.752  0.0   5.814
# 68  11.15  46.517  0.0   5.807
# 69  11.45  46.070  0.0   5.797
# 70  11.17  46.378  0.0   5.771
# 71  11.17  46.165  0.0   5.776
# 72  11.19  46.026  0.0   5.757
# 73  11.21  45.665  0.0   5.734
# 74  11.41  45.455  0.0   5.724
# 75  11.25  45.458  0.0   5.736
# 76  11.19  45.312  0.0   5.716
# 77  11.36  45.029  0.0   5.709
# 78  11.38  44.837  0.0   5.700
# 79  11.41  44.590  0.0   5.692
# 80  11.29  44.547  0.0   5.686
# 81  11.39  44.287  0.0   5.680
# 82  11.25  44.216  0.0   5.667
# 83  11.35  44.541  0.0   5.658
# 84  11.39  44.252  0.0   5.646
# 85  11.23  44.090  0.0   5.629
# 86  11.21  44.189  0.0   5.627
# 87  11.36  44.410  0.0   5.623
# 88  11.20  43.919  0.0   5.588
# 89  11.26  44.351  0.0   5.578
# 90  11.24  44.412  0.0   5.575
# 91  11.11  44.157  0.0   5.559
# 92  11.18  44.139  0.0   5.554
# 93  11.26  43.814  0.0   5.548
# 94  11.14  43.863  0.0   5.528
# 95  11.19  43.596  0.0   5.530
# 96  11.13  43.387  0.0   5.530
# 97  11.12  43.446  0.0   5.511
# 98  10.98  43.022  0.0   5.495
# 99  10.98  43.017  0.0   5.491
